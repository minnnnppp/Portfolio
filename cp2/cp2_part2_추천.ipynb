# %% [markdown]
# # Part 03. 추천시스템

# %% [markdown]
# # 🔍 라이브러리

# %%
#데이터셋 처리
import pandas as pd 
import numpy as np
import pyarrow.parquet as pq

#시각화
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc 
rc('font', family='AppleGothic') 			
plt.rcParams['axes.unicode_minus'] = False 

#시간 데이터 처리
from datetime import datetime, timedelta

#진행률 확인
from tqdm.notebook import tqdm # 진행률 확인
import warnings # 경고 무시
warnings.simplefilter("ignore")

# %% [markdown]
# # `- 전처리 부분 전처리 part로 옮겼습니다!`

# %% [markdown]
# ---

# %% [markdown]
# # 🔍 추천시스템 모델링

# %% [markdown]
# ## 1. 전처리된 데이터 로드

# %%
# parquet 변환된 데이터셋 불러오기
df = pd.read_parquet('../e-commerce/input/2019-Oct_new.parquet')
df.head(3)
# Out:
#            event_time event_type  product_id  \
# 0 2019-10-01 06:00:00       view     3900821
# 1 2019-10-01 06:00:01       view     1307067
# 2 2019-10-01 06:00:04       view     1004237
#
#                          category_code   brand        price    user_id  \
# 0  appliances.environment.water_heater    aqua    33.200001  554748717
# 1                   computers.notebook  lenovo   251.740005  550050854
# 2               electronics.smartphone   apple  1081.979980  535871217
#
#                            user_session event_date  event_month  event_day  \
# 0  9333dfbd-b87a-4708-9857-6336556b0fcc 2019-10-01           10          1
# 1  7c90fc70-0e80-4590-96f3-13c02c18c713 2019-10-01           10          1
# 2  c6bd7419-2748-4c56-95b4-8cec9ff8b80d 2019-10-01           10          1
#
#   day_of_week  event_hour  event_week
# 0     Tuesday           6          40
# 1     Tuesday           6          40
# 2     Tuesday           6          40

# %% [markdown]
# ## 2. Baseline Model
# ### 📌 통계기반 모델: event가 가장 많은 상품 상위 20개 일괄적으로 추천하는 모델

# %% [markdown]
# #### ✅ category code 변환
# - `Vectorization`을 위해 category code를 `'.'`으로 word 단위가 구분되는 문자열로 변환

# %% [markdown]
# #### 📌 데이터 필터링 및 train/test 데이터 분할

# %%
# 필요한 컬럼만 불러오기
df = df[['product_id','category_code','brand','user_id','event_week']]

# 카테고리 코드와 브랜드 type 변경 (필요한가)
df['category_code'] = df['category_code'].astype(object)
df['brand'] = df['brand'].astype(object)

# 카테고리 코드 구분자 '.' 를 공백으로 변경 -> TF IDF 구분 하려면 이렇게 해야 한다고 하는데
# 온점으로 그대로 둬도 괜찮은지 확인 해보자
df['category_code'] = df['category_code'].apply(lambda x: x.replace('.',' '))

# 카테고리에 브랜드 추가해서 성능에 변화가 있는지 확인 해보자 
# df['category_code'] = df['category_code']+df['brand']

# # 카운트 많은 5000개 만 추려냄 - 시간 오래 걸리니까 임시로
tmp = df.groupby('user_id').size().sort_values(ascending=False).head(5000).index
df = df[df.user_id.isin(tmp)].reset_index(drop=True)

# # 오래걸려서 샘플링 진행 (10프로)
df = df.sample(frac=0.5, replace = True, random_state = 1)

# train / test 분할
train = df[df.event_week<44]
test = df[df.event_week==44]

train = train[['user_id','product_id']].sort_values(by='user_id').reset_index(drop=True)
test = test[['user_id','product_id']].sort_values(by='user_id').reset_index(drop=True)

# %% [markdown]
# --------

# %%
# 회귀분석에서 y, y_pred 중 y의 역할 -> test 데이터로 평가할 때 필요
# y테이블 생성
from ipywidgets import FloatProgress

sol = test.groupby(['user_id'])['product_id'].agg({'unique'}).reset_index()
gt = {}
for user in tqdm(sol['user_id'].unique()): 
    gt[user] = list(sol[sol['user_id'] == user]['unique'].values[0])
# Out:
#   0%|          | 0/3943 [00:00<?, ?it/s]

# %%
# 추천
rec_df = pd.DataFrame()
rec_df['user_id'] = train['user_id'].unique()
rec_df
# Out:
#         user_id
# 0     430276841
# 1     460216566
# 2     463020196
# 3     470651295
# 4     479159590
# ...         ...
# 4966  564442389
# 4967  564458377
# 4968  564492792
# 4969  564514155
# 4970  564680336
#
# [4971 rows x 1 columns]

# %%
# 판매 상위 20개에 대해서 추천
tmp = df.groupby('product_id').size().nlargest(20).index
popular_rec_model = np.array(tmp)
popular_rec_model
# Out:
# array([1004767, 1005160, 1004856, 1005115, 1004741, 1004833, 1004249,
#        1004870, 1005239, 1004739, 1002544, 1004873, 1004785, 1004836,
#        1005161, 1005031, 1005159, 1004777, 1002524, 1004957], dtype=int64)

# %%
total_rec_list = {}
for user in tqdm(rec_df['user_id'].unique()):
    rec_list = []
    for rec in popular_rec_model[0:20]: 
        rec_list.append(rec)
    total_rec_list[user] = rec_list
# Out:
#   0%|          | 0/4971 [00:00<?, ?it/s]

# %%
# 평가지표를 직접 계산하는 클래스 생성: https://www.kaggle.com/code/chocozzz/04-goodbooks-10k-contents-based-model 의 코드 참고
import six
import math

# https://github.com/kakao-arena/brunch-article-recommendation/blob/master/evaluate.py

class evaluate():
    def __init__(self, recs, gt, topn=20):
        self.recs = recs
        self.gt = gt 
        self.topn = topn 
        
    def _ndcg(self):
        Q, S = 0.0, 0.0
        for u, seen in six.iteritems(self.gt):
            seen = list(set(seen))
            rec = self.recs.get(u, [])
            if not rec or len(seen) == 0:
                continue

            dcg = 0.0
            idcg = sum([1.0 / math.log(i + 2, 2) for i in range(min(len(seen), len(rec)))])
            for i, r in enumerate(rec):
                if r not in seen:
                    continue
                rank = i + 1
                dcg += 1.0 / math.log(rank + 1, 2)
            ndcg = dcg / idcg
            S += ndcg
            Q += 1
        return S / Q


    def _map(self):
        n, ap = 0.0, 0.0
        for u, seen in six.iteritems(self.gt):
            seen = list(set(seen))
            rec = self.recs.get(u, [])
            if not rec or len(seen) == 0:
                continue

            _ap, correct = 0.0, 0.0
            for i, r in enumerate(rec):
                if r in seen:
                    correct += 1
                    _ap += (correct / (i + 1.0))
            _ap /= min(len(seen), len(rec))
            ap += _ap
            n += 1.0
        return ap / n


    def _entropy_diversity(self):
        sz = float(len(self.recs)) * self.topn
        freq = {}
        for u, rec in six.iteritems(self.recs):
            for r in rec:
                freq[r] = freq.get(r, 0) + 1
        ent = -sum([v / sz * math.log(v / sz) for v in six.itervalues(freq)])
        return ent
    
    def _evaluate(self):
        print('MAP@%s: %s' % (self.topn, self._map()))
        print('NDCG@%s: %s' % (self.topn, self._ndcg()))
        print('EntDiv@%s: %s' % (self.topn, self._entropy_diversity()))

# %%
# top 20에 대해 보여주기
evaluate_func = evaluate(recs=total_rec_list, gt = gt, topn=20)
evaluate_func._evaluate()
# Out:
# MAP@20: 0.03470936329312459
# NDCG@20: 0.08250075125861263
# EntDiv@20: 2.995732273553991

# %% [markdown]
# ----

# %% [markdown]
# ## 3-1. 성능 개선 모델: TF-IDF를 사용한 Content-Based Model

# %%
# parquet 변환된 데이터셋 불러오기
df = pd.read_parquet('../e-commerce/input/2019-Oct_new.parquet')

# %%
# 필요한 컬럼만 불러오기
df = df[['product_id','category_code','brand','user_id','event_week']]

# 카테고리 코드와 브랜드 type 변경 (필요한가)
df['category_code'] = df['category_code'].astype(object)
df['brand'] = df['brand'].astype(object)

# 카테고리 코드 구분자 '.' 를 공백으로 변경 -> TF IDF 구분 하려면 이렇게 해야 한다고 하는데
# 온점으로 그대로 둬도 괜찮은지 확인 해보자
df['category_code'] = df['category_code'].apply(lambda x: x.replace('.',' '))

# 카테고리에 브랜드 추가해서 성능에 변화가 있는지 확인 해보자 
# df['category_code'] = df['category_code']+df['brand']

# # 카운트 많은 5000개 만 추려냄 - 시간 오래 걸리니까 임시로
tmp = df.groupby('user_id').size().sort_values(ascending=False).head(5000).index
df = df[df.user_id.isin(tmp)].reset_index(drop=True)

# # 오래걸려서 샘플링 진행 (50프로)
df = df.sample(frac=0.5, replace = True, random_state = 1)

# train / test 분할
train = df[df.event_week<44]
test = df[df.event_week==44]

train = train[['user_id','product_id']].sort_values(by='user_id').reset_index(drop=True)
test = test[['user_id','product_id']].sort_values(by='user_id').reset_index(drop=True)

# %%
# product 정보가 담긴 df 생성
# 레퍼런스의 books와 같은 데이터 프레임
tmp_df = df[['product_id','category_code']]
tmp_df = tmp_df.drop_duplicates()
tmp_df = tmp_df.sort_values(by='product_id').set_index('product_id')
tmp_df
# Out:
#                          category_code
# product_id
# 1000978         electronics smartphone
# 1001588         electronics smartphone
# 1002042         electronics smartphone
# 1002062         electronics smartphone
# 1002098         electronics smartphone
# ...                                ...
# 60500001    construction tools welding
# 60500002    construction tools welding
# 60500003    construction tools welding
# 60500004    construction tools welding
# 60500006    construction tools welding
#
# [35224 rows x 1 columns]

# %%
# 카운트(뷰,카트,퍼체이스 무관) 컬럼 생성
tmp_counts = df.groupby('product_id').size()

tmp_df['hit_count'] = tmp_counts
tmp_df = tmp_df.reset_index()
tmp_df
# Out:
#        product_id               category_code  hit_count
# 0         1000978      electronics smartphone        173
# 1         1001588      electronics smartphone        147
# 2         1002042      electronics smartphone          9
# 3         1002062      electronics smartphone         61
# 4         1002098      electronics smartphone        135
# ...           ...                         ...        ...
# 35219    60500001  construction tools welding         18
# 35220    60500002  construction tools welding         15
# 35221    60500003  construction tools welding          1
# 35222    60500004  construction tools welding          2
# 35223    60500006  construction tools welding          2
#
# [35224 rows x 3 columns]

# %%
tmp_df = tmp_df.sort_values(by='hit_count', ascending=False).reset_index(drop=True)
tmp_df
# Out:
#        product_id           category_code  hit_count
# 0         1004767  electronics smartphone       6388
# 1         1005160  electronics smartphone       6089
# 2         1004856  electronics smartphone       5817
# 3         1005115  electronics smartphone       4780
# 4         1004741  electronics smartphone       4555
# ...           ...                     ...        ...
# 35219    11600245       computers desktop          1
# 35220    28716053           apparel shoes          1
# 35221    28716051           apparel shoes          1
# 35222    21407070      electronics clocks          1
# 35223    28706633      apparel shoes keds          1
#
# [35224 rows x 3 columns]

# %%
# popular_rec_model 추천할거 없으면
popular_rec_model = tmp_df.sort_values(by='hit_count', ascending=False)['product_id'].values[0:20]
popular_rec_model
# 20번까지
# Out:
# array([1004767, 1005160, 1004856, 1005115, 1004741, 1004833, 1004249,
#        1004870, 1005239, 1004739, 1002544, 1004873, 1004785, 1004836,
#        1005161, 1005031, 1005159, 1004777, 1002524, 1004957], dtype=int64)

# %%
# 비교대상 만들기
sol = test.groupby(['user_id'])['product_id'].agg({'unique'}).reset_index()
gt = {}
for user in tqdm(sol['user_id'].unique()): 
    gt[user] = list(sol[sol['user_id'] == user]['unique'].values[0])
# Out:
#   0%|          | 0/3943 [00:00<?, ?it/s]

# %%
rec_df = pd.DataFrame()
rec_df['user_id'] = train['user_id'].unique()
rec_df
# Out:
#         user_id
# 0     430276841
# 1     460216566
# 2     463020196
# 3     470651295
# 4     479159590
# ...         ...
# 4966  564442389
# 4967  564458377
# 4968  564492792
# 4969  564514155
# 4970  564680336
#
# [4971 rows x 1 columns]

# %%
# tfidf 벡터화
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(tmp_df['category_code'])
print(tfidf_matrix.shape)
# Out:
# (35224, 150)

# %%
# 유사도 매트릭스 생성 - 코사인 유사도
from sklearn.metrics.pairwise import cosine_similarity
cosine_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)
cosine_matrix.shape
# Out:
# (35224, 35224)

# %%
# category_code와 id를 매핑할 dictionary를 생성해줍니다. 
product2id = {}
for i, c in enumerate(tmp_df['product_id']): product2id[i] = c

# id와 product title를 매핑할 dictionary를 생성해줍니다. 
id2product = {}
for i, c in product2id.items(): id2product[c] = i
    
# product_id와 title를 매핑할 dictionary를 생성해줍니다.
productid2product = {}
for i, j in zip(tmp_df['product_id'].values, tmp_df['product_id'].values):
    productid2product[i] = j

# %%
tmp_df['product_id'].head()
# Out:
# 0    1004767
# 1    1005160
# 2    1004856
# 3    1005115
# 4    1004741
# Name: product_id, dtype: int64

# %%
idx = id2product[1004767]  
sim_scores = [(product2id[i], c) for i, c in enumerate(cosine_matrix[idx]) if i != idx] 
sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse=True)
sim_scores[0:10]
# Out:
# [(1005160, 1.0),
#  (1004856, 1.0),
#  (1005115, 1.0),
#  (1004741, 1.0),
#  (1004833, 1.0),
#  (1004249, 1.0),
#  (1004870, 1.0),
#  (1005239, 1.0),
#  (1004739, 1.0),
#  (1002544, 1.0)]

# %%
train = pd.merge(train, tmp_df[['product_id', 'category_code']], how='left', on='product_id')
train.head()
# Out:
#      user_id  product_id                category_code
# 0  430276841     6000229       auto accessories alarm
# 1  430276841     5801376  electronics audio subwoofer
# 2  430276841     6000227       auto accessories alarm
# 3  430276841     5701084      auto accessories player
# 4  430276841     6000167       auto accessories alarm

# %% [markdown]
# - 예제

# %%
# 0. 학습셋에서 제목이 있는 경우에 대해서만 진행
tf_train = train[train['product_id'].notnull()].reset_index(drop=True)
tf_train['idx2product_id'] = tf_train['product_id'].apply(lambda x: id2product[x])
tf_train.head()
# Out:
#      user_id  product_id                category_code  idx2product_id
# 0  430276841     6000229       auto accessories alarm             980
# 1  430276841     5801376  electronics audio subwoofer            3395
# 2  430276841     6000227       auto accessories alarm             499
# 3  430276841     5701084      auto accessories player            1245
# 4  430276841     6000167       auto accessories alarm            1265

# %%
idx2product_id2product = {}
for i, j in zip(tf_train['idx2product_id'].values, tf_train['product_id'].values):
    idx2product_id2product[i] = j

# %%
# 1. 각 유저별로 관심 가진 제품의 목록을 수집 
user = 430276841
read_list = tf_train.groupby(['user_id'])['idx2product_id'].agg({'unique'}).reset_index()
seen = read_list[read_list['user_id'] == user]['unique'].values[0]
seen
# Out:
# array([  980,  3395,   499,  1245,  1265,  8893,  4594,   840,  2650,
#         3190,   999,   316,  5016,   349, 10937,  1981, 23507,  9566,
#         1074,  4360,  2674,   706,  1185,  3957,  1165,  5833,  2680,
#         1715,   709, 13648,  4074,   858,  5034,   846,  6112,   350,
#         4776, 17659,  5782,  6791,  1227,  2196,  1790,  8825, 18194,
#          746,  4448,   515,  4999,  6633,  5091,  1088,  2582,  8290,
#         5990,  6331,   859,  1662, 24686, 18398,   392, 11506,  3226,
#         1351,  2945,  5103, 23511,  2242,  5153,  3532,  6854,   524,
#         1109,  1418,  5336,  1040,  2384,  2603,  3446,  6225,  1505,
#        11111,  5796,  4472,  4756,  3726,  2773,  3876,  2388,   640,
#         4336,  2017, 12496,  7340,  7321, 13382,  2205,  8340,  8224,
#        15770, 10574,  2570,  4640,  1283,  3979, 23494,   723,  3972,
#         3508,  3635,  3036, 19428], dtype=int64)

# %%
# 2. 읽은 제품과 유사한 제품 추출 
## 733번째 책과 다른 책들간의 유사도 
cosine_matrix[3224]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
# 2. 관심가진 제품과 유사한 제품 추출 
total_cosine_sim = np.zeros(len(product2id))
for product_ in seen: 
    
    # 3. 모든 제품에 대해서 유사도를 더한 값을 계산 
    # 343번째 제품과 248의 유사도가 모두 결합된 유사도
    total_cosine_sim += cosine_matrix[product_]

# %%
total_cosine_sim
# Out:
# array([5.09981627, 5.09981627, 5.09981627, ..., 0.        , 6.35638293,
#        0.        ])

# %%
# 4. 3에서 유사도가 가장 높은 순서대로 추출
sim_scores = [(i, c) for i, c in enumerate(total_cosine_sim) if i not in seen] # 자기 자신을 제외한 영화들의 유사도 및 인덱스를 추출 
sim_scores = sorted(sim_scores, key = lambda x: x[1], reverse=True) # 유사도가 높은 순서대로 정렬 
sim_scores[0:20]
# Out:
# [(679, 63.28009086431688),
#  (689, 63.28009086431688),
#  (867, 63.28009086431688),
#  (915, 63.28009086431688),
#  (968, 63.28009086431688),
#  (1062, 63.28009086431688),
#  (1140, 63.28009086431688),
#  (1153, 63.28009086431688),
#  (1186, 63.28009086431688),
#  (1208, 63.28009086431688),
#  (1252, 63.28009086431688),
#  (1253, 63.28009086431688),
#  (1331, 63.28009086431688),
#  (1409, 63.28009086431688),
#  (1443, 63.28009086431688),
#  (1553, 63.28009086431688),
#  (1554, 63.28009086431688),
#  (1621, 63.28009086431688),
#  (1718, 63.28009086431688),
#  (1749, 63.28009086431688)]

# %%
product2id[356]
# Out:
# 1802037

# %%
tf_train['user_id'].unique()
# Out:
# array([430276841, 460216566, 463020196, ..., 564492792, 564514155,
#        564680336])

# %%
tf_train.head(3)
# Out:
#      user_id  product_id                category_code  idx2product_id
# 0  430276841     6000229       auto accessories alarm             980
# 1  430276841     5801376  electronics audio subwoofer            3395
# 2  430276841     6000227       auto accessories alarm             499

# %%
# 학습 진행 

## 전체 데이터에 대해서 진행 
total_rec_list = {}

#첫번째 리스트 
# train user_id로 묶어서 
read_list1 = train.groupby(['user_id'])['product_id'].agg({'unique'}).reset_index()
read_list2 = tf_train.groupby(['user_id'])['idx2product_id'].agg({'unique'}).reset_index()

# user_id 순환
for user in tqdm(train['user_id'].unique()):
    rec_list = []
        
    # 만약 TF-IDF 소속의 추천대상이라면 Contents 기반의 추천 
    if user in tf_train['user_id'].unique():
        # 1. 각 유저별로 구매한 상품 목록을 수집 
        seen = read_list2[read_list2['user_id'] == user]['unique'].values[0]
        # 2. 구매한 상품과 유사한 상품 추출 
        total_cosine_sim = np.zeros(len(product2id))
        for product_ in seen: 
            # 3. 모든 상품에 대해서 유사도를 더한 값을 계산 
            # 343번째 상품과 248의 유사도가 모두 결합된 유사도
            total_cosine_sim += cosine_matrix[product_]
            
        # 4. 3에서 유사도가 가장 높은 순서대로 추출
        sim_scores = [(productid2product[product2id[i]], c) for i, c in enumerate(total_cosine_sim) if i not in seen] # 자기 자신을 제외한 영화들의 유사도 및 인덱스를 추출 
        recs = sorted(sim_scores, key = lambda x: x[1], reverse=True)[0:300] # 유사도가 높은 순서대로 정렬 
        for rec in recs: 
            if rec[0] not in seen:
                rec_list.append(rec[0])   
        
    # 그렇지 않으면 인기도 기반의 추천 
    else: 
        seen = read_list1[read_list1['user_id'] == user]['unique'].values[0]
        for rec in popular_rec_model[0:400]:
            if rec[0] not in seen:
                rec_list.append(list(rec[0]))
                
    total_rec_list[user] = rec_list[0:20]
# Out:
#   0%|          | 0/4971 [00:00<?, ?it/s]

# %%
# 평가함수
import six # 파이썬 2, 3 호관성 라이브러리
import math

# https://github.com/kakao-arena/brunch-article-recommendation/blob/master/evaluate.py

class evaluate():
    def __init__(self, recs, gt, topn=100):
        self.recs = recs
        self.gt = gt 
        self.topn = topn 
        
    def _ndcg(self):
        Q, S = 0.0, 0.0
        for u, seen in six.iteritems(self.gt):
            seen = list(set(seen))
            rec = self.recs.get(u, [])
            if not rec or len(seen) == 0:
                continue

            dcg = 0.0
            idcg = sum([1.0 / math.log(i + 2, 2) for i in range(min(len(seen), len(rec)))])
            for i, r in enumerate(rec):
                if r not in seen:
                    continue
                rank = i + 1
                dcg += 1.0 / math.log(rank + 1, 2)
            ndcg = dcg / idcg
            S += ndcg
            Q += 1
        return S / Q


    def _map(self):
        # n : 개수, ap : average precision
        n, ap = 0.0, 0.0
        
        for u, seen in six.iteritems(self.gt): # six.iteritems는 .items와 같다.
            seen = list(set(seen))
            rec = self.recs.get(u, [])
            if not rec or len(seen) == 0:
                continue

            _ap, correct = 0.0, 0.0
            for i, r in enumerate(rec):
                if r in seen:
                    correct += 1
                    _ap += (correct / (i + 1.0))
            _ap /= min(len(seen), len(rec))
            ap += _ap
            n += 1.0
        return ap / n


    def _entropy_diversity(self):
        sz = float(len(self.recs)) * self.topn
        freq = {}
        for u, rec in six.iteritems(self.recs):
            for r in rec:
                freq[r] = freq.get(r, 0) + 1
        ent = -sum([v / sz * math.log(v / sz) for v in six.itervalues(freq)])
        return ent
    
    def _evaluate(self):
        print('MAP@%s: %s' % (self.topn, self._map()))
        print('NDCG@%s: %s' % (self.topn, self._ndcg()))

        print('EntDiv@%s: %s' % (self.topn, self._entropy_diversity()))

# %%
#평가
evaluate_func = evaluate(recs=total_rec_list, gt = gt, topn=20)
evaluate_func._evaluate()
# Out:
# MAP@20: 0.017148624592693736
# NDCG@20: 0.04917596785249336
# EntDiv@20: 6.029382092278079

# %% [markdown]
# -------

# %% [markdown]
# ## 3-2. 성능 개선 모델: `Word2Vec`을 사용한 Content-Based Model
# - https://www.kaggle.com/code/chocozzz/00-word2vec-1
# - https://www.kaggle.com/code/chocozzz/04-goodbooks-10k-contents-based-model

# %%
train = train[['product_id','category_code','user_id']].sort_values(by='user_id').reset_index(drop=True)
test = test[['product_id','category_code','user_id']].sort_values(by='user_id').reset_index(drop=True)
train.shape, test.shape
# Out:
# ((41030, 3), (8491, 3))

# %%
# product id: int -> str로 변환
train['product_id'] = train['product_id'].astype(str)
test['product_id'] = test['product_id'].astype(str)

# %% [markdown]
# -------

# %%
# userid 별 product id 구매 목록을 생성 
agg = train.groupby(['user_id'])['product_id'].agg({'unique'})
agg.head(20)
# Out:
#                                                       unique
# user_id
# 430276841  [5700402, 5700384, 5700576, 5801701, 6000094, ...
# 460216566  [1201512, 1201297, 1005216, 1307477, 1307489, ...
# 463020196  [1701552, 30900830, 30901117, 1700880, 1701490...
# 486578007  [7005328, 7004649, 7003167, 7005329, 7002775, ...
# 489062934  [1801623, 1004838, 1004659, 1004342, 1005017, ...
# 499386220  [1801929, 1800931, 1801551, 1801976, 1200617, ...
# 506000960  [1307279, 1005238, 1004078, 1305996, 1306651, ...
# 506009066  [1003992, 1004820, 1005062, 1004767, 1004814, ...
# 509166157  [1005032, 1004957, 1005069, 1004503, 1004500, ...
# 510335574  [1306954, 1307355, 1005160, 1307451, 1004957, ...
# 512363624  [1480741, 1480726, 1307460, 1480163, 1307015, ...
# 512363791  [1005160, 1005239, 1004741, 1004739, 1004833, ...
# 512364160  [8800773, 1004900, 8801039, 1004036, 1005238, ...
# 512365995  [1004863, 4200544, 1003306, 1004665, 1004238, ...
# 512366270  [28719197, 6902927, 14500096, 14500019, 287179...
# 512367358  [2701024, 2800591, 2800351, 2800596, 11700321,...
# 512367362  [3801235, 6301980, 11600133, 28716243, 3801167...
# 512367789  [1004442, 1005164, 12900085, 1003636, 1005066,...
# 512368482  [1004856, 1004249, 1004781, 1004227, 1005105, ...
# 512368585      [1004199, 1005217, 1004793, 1004950, 1005236]

# %%
# 유저별 구매 목록을 sentence에 넣기
sentence = []
for user_sentence in agg['unique'].values:
    sentence.append(list(user_sentence))

# %%
# Word2vec의 학습 진행 -> parameter reference: https://hoonzi-text.tistory.com/2
from gensim.models import Word2Vec

embedding_model = Word2Vec(sentence, size=20, window = 5, 
                           min_count=1, workers=4, sg=1)

# %%
# product_id가 2701024인 상품과 유사한? 아이텀 top 20 출력해보기
embedding_model.wv.most_similar(positive=['2701024'], topn=20)
# Out:
# [('14300312', 0.7671674489974976),
#  ('1005262', 0.7537975311279297),
#  ('3100267', 0.7170731425285339),
#  ('1305851', 0.6903489828109741),
#  ('17900077', 0.6858954429626465),
#  ('2701460', 0.6819285154342651),
#  ('1305976', 0.6705312728881836),
#  ('4600560', 0.6687020659446716),
#  ('28714725', 0.6658309698104858),
#  ('1004988', 0.6626853346824646),
#  ('12301124', 0.6544561386108398),
#  ('1303049', 0.6449756622314453),
#  ('5800957', 0.6413411498069763),
#  ('1801983', 0.6351058483123779),
#  ('6200080', 0.6282398700714111),
#  ('1003609', 0.6261202096939087),
#  ('3701399', 0.6239267587661743),
#  ('1306761', 0.6209348440170288),
#  ('6500779', 0.6208581924438477),
#  ('1801792', 0.6175357103347778)]

# %%
# 전체 상품에 대해 진행
from ipywidgets import FloatProgress

total_rec_list = {}
purchase_list1 = agg.reset_index()

purchase_list = train.groupby(['user_id'])['product_id'].agg({'unique'}).reset_index()
for user in train['user_id'].unique():
    rec_list = []     
    purchase = purchase_list1[purchase_list1['user_id'] == user]['unique'].values[0]
    word2vec_dict = {}
    for product in purchase: 
        for i in embedding_model.wv.most_similar(positive=[product], topn=20):
            if i[0] not in purchase: 
                if i[0] not in word2vec_dict.keys(): 
                    word2vec_dict[i[0]] = i[1]
                else:
                    word2vec_dict[i[0]] += i[1]
                
    rec_list = list(dict(sorted(word2vec_dict.items(), key = lambda x: x[1], reverse=True)).keys())
    total_rec_list[user] = rec_list[0:20]

# %%
evaluate_func = evaluate(recs=total_rec_list, gt = gt)
evaluate_func._evaluate()
# Out:
# MAP@20: 0.0
# NDCG@20: 0.0
# EntDiv@20: 5.7364575748113715

# %% [markdown]
# #### ✅ category_code를 통한 유사도 계산

# %%
agg = train.groupby(['product_id'])['category_code'].agg({'unique'}).reset_index()
agg.head()
# Out:
#   product_id                    unique
# 0    1000978  [electronics smartphone]
# 1    1001588  [electronics smartphone]
# 2    1002042  [electronics smartphone]
# 3    1002062  [electronics smartphone]
# 4    1002098  [electronics smartphone]

# %%
# 카테고리 간의 유사도 계산 
sentence = []
for user_sentence in agg['unique'].values:
    sentence.append(list(user_sentence))

# %%
from gensim.models import doc2vec

doc_vectorizer = doc2vec.Doc2Vec(
    dm=0,            # PV-DBOW / default 1
    dbow_words=1,    # w2v simultaneous with DBOW d2v / default 0
    window=10,        # distance between the predicted word and context words
    vector_size=100,        # vector size
    alpha=0.025,     # learning-rate
    seed=1234,
    min_count=5,    # ignore with freq lower
    min_alpha=0.025, # min learning-rate
    workers=4,   # multi cpu
    hs = 1,          # hierar chical softmax / default 0
    negative = 10   # negative sampling / default 5
)

# %%
from collections import namedtuple

# 학습하기 위해 CategorizedDocument라는 클래스에 category_code와 product_id 넣기
CategorizedDocument = namedtuple('CategorizedDocument',  ['words', 'tags'])
categorized_train_docs = [CategorizedDocument(c, [d]) for c, d in agg[['unique', 'product_id']].values]

categorized_train_docs
# reference: https://velog.io/@jewon119/Python-%EC%8B%AC%ED%99%94-NamedTuple#4-namedtuple-%ED%99%9C%EC%9A%A9-%EC%98%88%EC%8B%9C
# Out:
# [CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1000978']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1001588']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002042']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002062']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002098']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002099']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002100']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002101']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002102']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002225']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002266']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002367']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002396']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002398']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002460']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002482']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002484']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002494']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002497']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002524']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002525']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002528']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002532']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002535']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002536']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002538']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002540']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002542']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002544']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002545']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002547']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002548']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002550']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002628']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002629']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002633']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002634']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002662']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002678']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002724']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002796']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002827']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002876']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002881']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002902']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002906']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002923']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002929']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002974']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002987']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1002995']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003013']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003014']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003050']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003073']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003074']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003078']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003096']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003105']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003112']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003114']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003129']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003141']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003153']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003176']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003177']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003183']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003195']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003208']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003221']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003222']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003230']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003235']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003281']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003285']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003293']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003298']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003304']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003305']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003306']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003307']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003308']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003309']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003310']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003311']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003312']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003313']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003314']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003315']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003316']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003317']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003318']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003319']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003328']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003333']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003338']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003339']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003347']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003363']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003371']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003391']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003416']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003418']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003428']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003435']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003441']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003442']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003447']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003456']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003461']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003475']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003484']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003499']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003507']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003509']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003523']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003524']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003525']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003527']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003532']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003533']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003534']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003535']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003548']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003549']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003551']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003566']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003571']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003592']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003599']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003608']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003609']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003613']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003614']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003622']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003636']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003652']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003656']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003665']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003673']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003705']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003706']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003707']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003709']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003712']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003713']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003714']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003726']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003734']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003735']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003746']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003747']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003750']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003751']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003752']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003756']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003761']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003768']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003769']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003770']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003771']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003772']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003774']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003777']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003778']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003798']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003800']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003801']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003802']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003811']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003854']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003855']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003856']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003857']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003860']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003862']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003864']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003865']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003866']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003869']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003870']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003877']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003879']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003883']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003890']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003892']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003894']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003896']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003898']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003899']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003901']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003906']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003907']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003910']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003911']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003913']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003922']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003931']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003934']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003936']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003937']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003938']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003942']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003943']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003947']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003948']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003949']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003951']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003952']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003954']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003965']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003969']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003973']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003978']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003982']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003983']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003988']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003989']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003991']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1003992']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004014']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004015']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004016']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004024']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004026']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004033']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004034']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004035']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004036']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004038']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004042']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004059']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004060']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004062']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004077']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004078']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004080']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004097']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004100']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004104']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004111']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004116']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004121']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004129']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004133']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004136']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004138']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004139']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004140']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004142']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004143']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004144']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004145']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004147']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004149']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004152']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004155']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004156']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004157']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004158']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004159']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004161']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004166']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004167']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004168']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004173']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004174']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004175']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004184']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004185']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004188']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004189']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004190']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004191']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004192']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004194']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004196']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004197']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004199']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004205']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004208']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004209']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004210']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004211']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004213']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004214']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004219']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004223']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004224']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004225']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004226']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004227']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004228']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004229']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004230']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004231']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004232']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004233']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004234']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004235']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004236']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004237']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004238']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004239']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004240']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004241']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004243']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004244']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004245']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004246']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004247']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004248']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004249']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004250']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004252']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004253']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004254']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004255']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004256']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004257']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004258']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004259']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004260']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004266']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004281']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004284']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004300']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004302']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004303']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004305']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004308']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004309']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004317']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004318']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004320']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004321']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004322']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004323']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004324']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004340']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004341']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004342']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004355']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004356']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004357']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004358']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004359']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004361']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004362']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004363']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004372']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004375']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004385']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004386']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004388']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004389']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004393']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004395']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004402']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004403']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004404']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004405']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004406']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004409']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004413']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004415']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004426']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004427']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004428']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004429']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004432']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004433']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004434']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004435']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004436']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004440']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004441']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004442']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004444']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004445']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004446']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004449']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004450']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004452']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004455']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004460']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004461']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004462']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004464']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004467']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004468']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004475']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004477']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004489']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004491']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004493']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004495']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004496']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004497']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004500']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004502']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004503']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004505']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004508']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004509']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004512']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004523']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004524']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004525']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004528']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004529']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004530']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004531']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004532']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004536']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004542']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004543']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004544']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004545']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004548']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004553']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004562']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004564']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004565']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004566']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004573']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004574']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004575']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004578']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004579']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004582']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004583']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004585']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004587']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004588']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004589']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004596']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004597']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004599']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004603']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004604']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004605']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004606']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004611']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004617']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004625']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004627']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004648']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004650']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004653']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004655']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004657']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004659']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004660']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004661']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004662']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004663']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004665']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004666']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004668']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004669']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004670']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004671']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004674']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004681']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004682']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004683']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004691']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004693']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004694']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004695']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004698']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004703']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004704']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004708']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004709']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004713']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004714']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004715']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004716']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004717']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004718']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004720']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004721']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004723']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004725']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004726']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004727']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004728']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004729']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004730']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004732']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004733']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004735']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004736']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004737']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004738']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004739']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004740']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004741']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004742']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004743']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004748']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004749']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1004750']),
# ...
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005191']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005192']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005193']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005195']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005196']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005197']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005198']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005199']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005201']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005202']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005203']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005204']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005205']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005206']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005207']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005208']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005209']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005210']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005211']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005212']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005213']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005214']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005215']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005216']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005217']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005218']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005219']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005220']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005221']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005223']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005225']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005228']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005229']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005230']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005231']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005232']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005233']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005234']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005235']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005236']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005237']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005238']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005239']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005241']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005242']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005243']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005244']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005246']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005248']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005250']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005251']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005252']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005253']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005254']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005256']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005257']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005258']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005259']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005260']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005261']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005262']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005263']),
#  CategorizedDocument(words=array(['electronics smartphone'], dtype=object), tags=['1005264']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10200950']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10200968']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201146']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201150']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201152']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201153']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201158']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201177']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201206']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201389']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201400']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201456']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201470']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201512']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201516']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201522']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201531']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201547']),
#  CategorizedDocument(words=array(['kids dolls'], dtype=object), tags=['10201627']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400005']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400009']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400013']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400018']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400026']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400029']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400190']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400196']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400294']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400322']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400336']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400392']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400393']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400404']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400414']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400438']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400460']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400463']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400474']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400487']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400488']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400527']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400597']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400600']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400608']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400626']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400631']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400667']),
#  CategorizedDocument(words=array(['kids toys'], dtype=object), tags=['10400703']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900003']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900026']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900029']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900030']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900041']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900055']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900062']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900096']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900113']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900114']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900115']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900127']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900135']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900136']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900154']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900162']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900168']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900186']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900194']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900224']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900227']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900228']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900233']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900250']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900291']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900301']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900305']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900306']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900314']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900315']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900324']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900325']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900328']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900338']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900343']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900348']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900349']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900356']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900368']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900384']),
#  CategorizedDocument(words=array(['appliances kitchen mixer'], dtype=object), tags=['10900395']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000000']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000006']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000016']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000078']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000085']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000088']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000096']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000097']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000101']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000112']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000126']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000136']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000138']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000145']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000153']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000168']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000171']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000228']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000231']),
#  CategorizedDocument(words=array(['appliances kitchen toster'], dtype=object), tags=['11000241']),
#  ...]

# %%
doc_vectorizer.build_vocab(categorized_train_docs)      # 학습을 진행할 사전 맏들기
print(str(doc_vectorizer))
# Out:
# Doc2Vec(dbow+w,d100,n10,hs,w10,mc5,s0.001,t4)

# %%
# 벡터 문서 학습
from time import time
start = time()

for epoch in tqdm(range(3)):
    doc_vectorizer.train(categorized_train_docs, total_examples=doc_vectorizer.corpus_count, epochs=doc_vectorizer.iter)
    doc_vectorizer.alpha -= 0.002 # decrease the learning rate
    doc_vectorizer.min_alpha = doc_vectorizer.alpha # fix the learning rate, no decay

end = time()
print("During Time: {}".format(end-start))
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# During Time: 3.8909950256347656

# %%
doc_vectorizer.docvecs.most_similar('1001588', topn=20)     # product_id = '1001588'인 상품을 볼 때 관련성 높은 20개 상품 추천해주기
# Out:
# [('1004489', 0.38649502396583557),
#  ('3701096', 0.3798837661743164),
#  ('1004932', 0.37513405084609985),
#  ('1701281', 0.37443262338638306),
#  ('4804418', 0.36896592378616333),
#  ('1003769', 0.34862399101257324),
#  ('28719199', 0.33914196491241455),
#  ('5800646', 0.3313061594963074),
#  ('11600011', 0.3307732939720154),
#  ('4804205', 0.32918450236320496),
#  ('1004830', 0.3271191120147705),
#  ('1005175', 0.3241901695728302),
#  ('2800659', 0.3232332766056061),
#  ('28719264', 0.31995317339897156),
#  ('1004250', 0.3171292543411255),
#  ('28719493', 0.316822350025177),
#  ('28716184', 0.31601765751838684),
#  ('4803014', 0.3155464231967926),
#  ('28719776', 0.31500279903411865),
#  ('4804423', 0.31188496947288513)]

# %%
# 전체 상품에 대해서 진행 
total_rec_list = {}

purchase_list1 = train.groupby(['user_id'])['product_id'].agg({'unique'}).reset_index()
# read_list2 = train[train['type'] == '1'].groupby(['user_id'])['book_id'].agg({'unique'}).reset_index()

for user in train['user_id'].unique():
    rec_list = []
    bought = purchase_list1[purchase_list1['user_id'] == user]['unique'].values[0]
    doc2vec_dict = {}
    for product in bought: 
        for i in doc_vectorizer.docvecs.most_similar(positive=[product], topn=20): 
            if i[0] not in doc2vec_dict.keys(): 
                doc2vec_dict[i[0]] = i[1]
            else:
                doc2vec_dict[i[0]] += i[1]

    rec_list = list(dict(sorted(doc2vec_dict.items(), key = lambda x: x[1], reverse=True)).keys())
    # else:
    #     seen = purchase_list1[purchase_list1['user_id'] == user]['unique'].values[0]
    #     for rec in popular_rec_model[0:300]:
    #         if rec not in seen:
    #             rec_list.append(rec)

    total_rec_list[user] = rec_list[0:20]

# %%
evaluate_func = evaluate(recs=total_rec_list, gt = gt, topn=20)
evaluate_func._evaluate()
# Out:
# MAP@20: 0.001588630171801049
# NDCG@20: 0.005573220462657566
# EntDiv@20: 7.981385547798531
