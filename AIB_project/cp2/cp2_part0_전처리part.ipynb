# %% [markdown]
# # 전처리 Part

# %% [markdown]
# ## Import Libraries

# %%
# !pip install pyarrow

# %%
import pandas as pd 
import numpy as np
import pyarrow.parquet as pq
from datetime import datetime, timedelta
import datetime as dt

# %% [markdown]
# ## Import CSV
# - 데이터셋 불러오기
#   1. 2019년 10월
#   2. 2019년 11월

# %%
# %%time
df_oct = pd.read_csv('../e-commerce/input/2019-Oct.csv')
# Out:
# Wall time: 5min 18s

# %%
# %%time
df_nov = pd.read_csv('../e-commerce/input/2019-Nov.csv')

# %%
# %%time 
#2019년 12월 코호트 분석용 4개 컬럼만 불러옴
df_dec = pd.read_csv('../e-commerce/input/2019-Dec.csv', usecols=['event_time','event_type','user_id','category_code','price'])
# Out:
# Wall time: 1min 37s

# %%
# %%time
df_jan = pd.read_csv('../e-commerce/input/2020-Jan.csv', usecols=['event_time','event_type','user_id','category_code','price'])
# Out:
# Wall time: 1min 19s

# %%
# %%time
df_feb = pd.read_csv('../e-commerce/input/2020-Feb.csv', usecols=['event_time','event_type','user_id','category_code','price'])
# Out:
# Wall time: 1min 17s

# %%
# %%time
df_mar = pd.read_csv('../e-commerce/input/2020-Mar.csv', usecols=['event_time','event_type','user_id','category_code','price'])
# Out:
# Wall time: 1min 12s

# %%
# %%time
df_apr = pd.read_csv('../e-commerce/input/2020-Apr.csv', usecols=['event_time','event_type','user_id','category_code','price'])
# Out:
# Wall time: 1min 26s

# %% [markdown]
# ## Export Parquet
# - 데이터 압축을 위해 parqeut 자료형으로 내보내기

# %%
# %%time
df_oct.to_parquet('../e-commerce/input/2019-Oct.parquet', engine='pyarrow', index=False)
df_nov.to_parquet('../e-commerce/input/2019-Nov.parquet', engine='pyarrow', index=False)
# Out:
# Wall time: 4min 49s

# %%
# %%time
df_dec.to_parquet('../e-commerce/input/2019-Dec.parquet', engine='pyarrow', index=False)
# Out:
# Wall time: 47.5 s

# %%
# %%time
df_jan.to_parquet('../e-commerce/input/2020-Jan.parquet', engine='pyarrow', index=False)
# Out:
# Wall time: 32.2 s

# %%
# %%time
df_feb.to_parquet('../e-commerce/input/2020-Feb.parquet', engine='pyarrow', index=False)
# Out:
# Wall time: 31.7 s

# %%
# %%time
df_mar.to_parquet('../e-commerce/input/2020-Mar.parquet', engine='pyarrow', index=False)
# Out:
# Wall time: 36.4 s

# %%
# %%time
df_apr.to_parquet('../e-commerce/input/2020-Apr.parquet', engine='pyarrow', index=False)
# Out:
# Wall time: 48.3 s

# %% [markdown]
# ## Import Parquet
# - parqet 불러오기

# %%
# %%time
df_oct = pd.read_parquet('../e-commerce/input/2019-Oct.parquet')
df_nov = pd.read_parquet('../e-commerce/input/2019-Nov.parquet')
# Out:
# Wall time: 2min 52s

# %%
df_dec = pd.read_parquet('../e-commerce/input/2019-Dec.parquet')

# %%
df_jan = pd.read_parquet('../e-commerce/input/2020-Jan.parquet')

# %%
df_feb = pd.read_parquet('../e-commerce/input/2020-Feb.parquet')

# %%
df_mar = pd.read_parquet('../e-commerce/input/2020-Mar.parquet')

# %%
df_apr = pd.read_parquet('../e-commerce/input/2020-Apr.parquet')

# %% [markdown]
# ## Drop category_id
# - 불필요한 컬럼 제거

# %%
# %%time
df_oct = df_oct.drop('category_id', axis=1)
df_nov = df_nov.drop('category_id', axis=1)
# Out:
# Wall time: 1min 5s

# %% [markdown]
# ## Missing values
# - `user_session`
#   - 10월 : 2개 특성 확인 후 수작업으로 해결
#   - 11월 : 10개 특성 확인 후 수작업으로 해결
#
#   - ※ 나중에는 이정도면 그냥 drop 하자
# - `category_id`, `category_code`
#   - 'unknown'으로 대체

# %% [markdown]
# ### Oct.

# %%
# 결측치 수 확인
df_oct.isnull().sum()
# Out:
# event_time              0
# event_type              0
# product_id              0
# category_code    13515609
# brand             6117080
# price                   0
# user_id                 0
# user_session            2
# dtype: int64

# %%
# user_session이 결측치인 경우의 user_id 확인 
df_oct[df_oct.user_session.isnull()]
# Out:
#                        event_time event_type  product_id  \
# 7157243   2019-10-06 14:26:10 UTC       cart     1801723
# 33940774  2019-10-25 10:36:14 UTC       cart     1004767
#
#                    category_code    brand   price    user_id user_session
# 7157243     electronics.video.tv      tcl  135.65  557388939         None
# 33940774  electronics.smartphone  samsung  246.52  549825742         None

# %% [markdown]
# ### Oct. - Case 1
# - 4번->5번
#   - view에서 cart로 넘어가면서 session에 오류가 생긴듯
#   - 1번->2번의 경우를 참고하여
#   - 5번의 user_session을 4번과 동일하게 설정한다.

# %%
df_oct[df_oct.user_id==557388939].reset_index().drop('index', axis=1)
# Out:
#                 event_time event_type  product_id         category_code  \
# 0  2019-10-06 14:20:18 UTC       view    50700029                  None
# 1  2019-10-06 14:22:05 UTC       view     1801766  electronics.video.tv
# 2  2019-10-06 14:23:25 UTC       cart     1801766  electronics.video.tv
# 3  2019-10-06 14:23:50 UTC       view     1801766  electronics.video.tv
# 4  2019-10-06 14:25:18 UTC       view     1801723  electronics.video.tv
# 5  2019-10-06 14:26:10 UTC       cart     1801723  electronics.video.tv
# 6  2019-10-07 10:15:39 UTC       view     1801723  electronics.video.tv
#
#    brand   price    user_id                          user_session
# 0   yema   48.65  557388939  69e2aec8-4022-45cc-9fb0-48300f6b018e
# 1  artel  150.43  557388939  e24814e3-6587-4f74-8f92-6ac44b9b94ba
# 2  artel  150.43  557388939  e24814e3-6587-4f74-8f92-6ac44b9b94ba
# 3  artel  150.43  557388939  27eb4e3f-4951-41f5-9ca1-2c8ea537215b
# 4    tcl  135.65  557388939  9c11ac2d-5c56-4994-87e4-ea077ab0ab45
# 5    tcl  135.65  557388939                                  None
# 6    tcl  135.65  557388939  083ceaa9-32d0-4e45-a67c-40bfaba0a275

# %%
# ndex 값 추출하여 
tmp = df_oct[(df_oct.user_id==557388939) & (df_oct.user_session.isnull())].index[0]

# 4번의 user_session 값으로 대체
df_oct.loc[tmp,'user_session'] = '9c11ac2d-5c56-4994-87e4-ea077ab0ab45'

# 결과 확인
df_oct[df_oct.user_id==557388939].reset_index().drop('index', axis=1)
# Out:
#                 event_time event_type  product_id         category_code  \
# 0  2019-10-06 14:20:18 UTC       view    50700029                  None
# 10  samsung  246.52  549825742                                  None

# %%
# case2의 경우의 index 값 추출하여 
tmp = df_oct[(df_oct.user_id==549825742) & (df_oct.user_session.isnull())].index[0]

# 바로 앞의(9번) user_session 값으로 대체
df_oct.loc[tmp,'user_session'] = '56fc550f-2ac9-4baf-a7eb-1d40320560a8'

# 결과 확인
df_oct[df_oct.user_id==549825742].reset_index().drop('index', axis=1)
# Out:
#                  event_time event_type  product_id           category_code  \
# 0   2019-10-25 09:01:50 UTC       view     1004767  electronics.smartphone
# 1   2019-10-25 09:12:12 UTC       cart     1004767  electronics.smartphone
# 2   2019-10-25 09:12:42 UTC       cart     1004767  electronics.smartphone
# 3   2019-10-25 09:12:52 UTC       cart     1004767  electronics.smartphone
# 4   2019-10-25 09:17:05 UTC       cart     1004767  electronics.smartphone
# 5   2019-10-25 09:49:33 UTC       view     1004433  electronics.smartphone
# 6   2019-10-25 09:50:12 UTC       view     1004434  electronics.smartphone
# 7   2019-10-25 09:51:50 UTC       view     1003548  electronics.smartphone
# 8   2019-10-25 09:52:44 UTC       view     1000978  electronics.smartphone
# 9   2019-10-25 09:53:22 UTC       view     1004990  electronics.smartphone
# 10  2019-10-25 10:36:14 UTC       cart     1004767  electronics.smartphone
#
#       brand   price    user_id                          user_session
# 0   samsung  246.52  549825742  aac8b299-4355-4c25-bbfe-c0369f19a3ce
# 1   samsung  246.52  549825742  aac8b299-4355-4c25-bbfe-c0369f19a3ce
# 2   samsung  246.52  549825742  aac8b299-4355-4c25-bbfe-c0369f19a3ce
# 3   samsung  246.52  549825742  aac8b299-4355-4c25-bbfe-c0369f19a3ce
# 4   samsung  246.52  549825742  aac8b299-4355-4c25-bbfe-c0369f19a3ce
# 5   samsung  257.15  549825742  56fc550f-2ac9-4baf-a7eb-1d40320560a8
# 6   samsung  257.15  549825742  56fc550f-2ac9-4baf-a7eb-1d40320560a8
# 7   samsung  282.84  549825742  56fc550f-2ac9-4baf-a7eb-1d40320560a8
# 8   samsung  333.49  549825742  56fc550f-2ac9-4baf-a7eb-1d40320560a8
# 9      oppo  257.38  549825742  56fc550f-2ac9-4baf-a7eb-1d40320560a8
# 10  samsung  246.52  549825742  56fc550f-2ac9-4baf-a7eb-1d40320560a8

# %% [markdown]
# ### Nov.
# - 10가지
# - 일단 하나하나 채워주긴 했는데 개수가 너무 작아서 전체 데이터에 영향 크게 안줄거 같다.
#   - 다음에는 이런 경우 그냥 drop하자

# %%
# 결측치 수 확인
df_nov.isnull().sum()
# Out:
# event_time              0
# event_type              0
# product_id              0
# category_code    21898171
# brand             9224078
# price                   0
# user_id                 0
# user_session           10
# dtype: int64

# %%
# user_session이 결측치인 경우의 user_id 확인 
df_nov[df_nov.user_session.isnull()]
# Out:
#                        event_time event_type  product_id  \
# 14771091  2019-11-09 15:32:27 UTC       cart    19700004
# 14991783  2019-11-09 17:15:24 UTC       cart     1005083
# 21436266  2019-11-13 04:02:03 UTC       cart     4804008
# 21765703  2019-11-13 07:18:35 UTC       cart     1004767
# 55027396  2019-11-23 12:53:50 UTC       cart     7600528
# 57521839  2019-11-25 05:04:42 UTC       cart     1802104
# 57690742  2019-11-25 07:03:38 UTC       cart    21403753
# 59356970  2019-11-26 07:48:12 UTC       cart     4804718
# 60920894  2019-11-27 07:02:20 UTC       cart    12719553
# 65449633  2019-11-29 17:25:56 UTC       cart     1005116
#
#                         category_code    brand    price    user_id  \
# 14771091                         None  kabrita    37.77  539704497
# 14991783       electronics.smartphone    honor   566.27  568843390
# 21436266  electronics.audio.headphone  bluedio    97.81  570411102
# 21765703       electronics.smartphone  samsung   243.51  570878749
# 55027396                         None  tp-link    16.73  575357602
# 57521839         electronics.video.tv      arg   360.09  573722572
# 57690742           electronics.clocks     None   181.47  576301354
# 59356970  electronics.audio.headphone    apple   334.58  576935861
# 60920894                         None     None    55.60  577167045
# 65449633       electronics.smartphone    apple  1001.42  579123407
#
#          user_session
# 14771091         None
# 14991783         None
# 21436266         None
# 21765703         None
# 55027396         None
# 57521839         None
# 57690742         None
# 59356970         None
# 60920894         None
# 65449633         None

# %% [markdown]
# ### Nov. - Case 1

# %%
df_nov[df_nov.user_id==539704497].reset_index().drop('index', axis=1).head()
# Out:
#                 event_time event_type  product_id category_code    brand  \
# 0  2019-11-09 15:32:06 UTC       view    19700004          None  kabrita
# 1  2019-11-09 15:32:27 UTC       cart    19700004          None  kabrita
# 2  2019-11-09 15:32:32 UTC       view    19700004          None  kabrita
# 3  2019-11-09 15:38:25 UTC       view    19700004          None  kabrita
# 4  2019-11-09 15:38:34 UTC       cart    19700004          None  kabrita
#
#    price    user_id                          user_session
# 0  37.77  539704497  e82ecde4-5c22-49e6-84cc-d63def4ff7d3
# 1  37.77  539704497                                  None
# 2  37.77  539704497  e1e253ec-b564-48a8-8ff5-4e86bacb49f3
# 3  37.77  539704497  e1e253ec-b564-48a8-8ff5-4e86bacb49f3
# 4  37.77  539704497  e1e253ec-b564-48a8-8ff5-4e86bacb49f3

# %%
# index 값 추출하여 
tmp = df_nov[(df_nov.user_id==539704497) & (df_nov.user_session.isnull())].index[0]

# 바로 앞의(9번) user_session 값으로 대체
df_nov.loc[tmp,'user_session'] = 'e82ecde4-5c22-49e6-84cc-d63def4ff7d3'

# 결과 확인
df_nov[df_nov.user_id==539704497].reset_index().drop('index', axis=1).head()
# Out:
#                 event_time event_type  product_id category_code    brand  \
# 0  2019-11-09 15:32:06 UTC       view    19700004          None  kabrita
# 1  2019-11-09 15:32:27 UTC       cart    19700004          None  kabrita
# 2  2019-11-09 15:32:32 UTC       view    19700004          None  kabrita
# 3  2019-11-09 15:38:25 UTC       view    19700004          None  kabrita
# 4  2019-11-09 15:38:34 UTC       cart    19700004          None  kabrita
#
#    price    user_id                          user_session
# 0  37.77  539704497  e82ecde4-5c22-49e6-84cc-d63def4ff7d3
# 1  37.77  539704497  e82ecde4-5c22-49e6-84cc-d63def4ff7d3
# 2  37.77  539704497  e1e253ec-b564-48a8-8ff5-4e86bacb49f3
# 3  37.77  539704497  e1e253ec-b564-48a8-8ff5-4e86bacb49f3
# 42  cd58e572-036d-4423-a4eb-81dec5bffe2a
# 43  cd58e572-036d-4423-a4eb-81dec5bffe2a
# 44  cd58e572-036d-4423-a4eb-81dec5bffe2a
# 45  82f502b2-a33a-4cc0-9070-bb38549801a2
# 46  82f502b2-a33a-4cc0-9070-bb38549801a2
# 47  82f502b2-a33a-4cc0-9070-bb38549801a2
# 48  cd58e572-036d-4423-a4eb-81dec5bffe2a
# 49  cd58e572-036d-4423-a4eb-81dec5bffe2a
# 50  cd58e572-036d-4423-a4eb-81dec5bffe2a
# 51  69d57d4a-9090-46fb-9cac-2f042cb0844b
# 52  576b9dc9-9e6a-46d7-88ea-19fcf6ce0131
# 53  f20129b7-272a-48b9-951a-5ed3b82b1413
# 54  0339bb2c-9c13-4c50-ad61-8dff39677b44
# 55  9039a30a-2c96-4962-ba4b-022bffa2984c
# 56  1a3afbae-e936-44db-8607-4722faad2ac4
# 57  dfb6c6ea-dc5a-44cd-ada8-713feb0047e6
# 58  067afb3b-f8d0-49b1-ac0c-144a9200b63e
# 59  4b633318-485e-4d49-bb0b-bb987c88783d

# %%
# index 값 추출하여 
tmp = df_nov[(df_nov.user_id==568843390) & (df_nov.user_session.isnull())].index[0]

# 바로 앞의(9번) user_session 값으로 대체
df_nov.loc[tmp,'user_session'] = '196aabe5-0f21-4436-b607-b75cf9fceb15'

# 결과 확인
df_nov[df_nov.user_id==568843390].reset_index().drop('index', axis=1)
# Out:
#                  event_time event_type  product_id  \
# 0   2019-11-08 07:14:34 UTC       view     1005169
# 1   2019-11-08 09:28:14 UTC       view     1005169
# 2   2019-11-08 12:14:23 UTC       view     1005169
# 3   2019-11-08 13:35:31 UTC       view     1005169
# 4   2019-11-08 14:09:21 UTC       view     1005169
# 5   2019-11-08 15:03:25 UTC       view     1005169
# 6   2019-11-09 03:15:37 UTC       view     1005169
# 7   2019-11-09 03:30:44 UTC       view     1005169
# 8   2019-11-09 07:32:50 UTC       view     1005169
# 9   2019-11-09 09:06:44 UTC       view     1005169
# 10  2019-11-09 09:55:41 UTC       view     1005169
# 11  2019-11-09 10:13:39 UTC       view     1005169
# 12  2019-11-09 10:38:48 UTC       view     1005083
# 13  2019-11-09 10:42:01 UTC       view     4201530
# 14  2019-11-09 10:42:09 UTC       view     1005082
# 15  2019-11-09 11:48:40 UTC       view     1005082
# 16  2019-11-09 14:13:10 UTC       view     1005082
# 17  2019-11-09 14:15:01 UTC       view     1005083
# 18  2019-11-09 14:15:56 UTC       view     1004813
# 19  2019-11-09 14:17:25 UTC       view     1005169
# 20  2019-11-09 14:18:57 UTC       view    18001599
# 21  2019-11-09 14:20:42 UTC       view     1005083
# 22  2019-11-09 14:21:41 UTC       view     1004754
# 23  2019-11-09 14:26:18 UTC       view     1004754
# 24  2019-11-09 15:34:31 UTC       view     1004754
# 25  2019-11-09 16:15:47 UTC       view     1004754
# 26  2019-11-09 17:11:29 UTC       view     1005083
# 27  2019-11-09 17:15:24 UTC       cart     1005083
# 28  2019-11-09 17:16:37 UTC       view     1005083
# 29  2019-11-09 17:25:59 UTC       view     1005083
# 19  9da8c2c7-5191-4124-9907-83440198093a
# 20  9da8c2c7-5191-4124-9907-83440198093a
# 21                                  None

# %%
# index 값 추출하여 
tmp = df_nov[(df_nov.user_id==570411102) & (df_nov.user_session.isnull())].index[0]

# 바로 앞의(9번) user_session 값으로 대체
df_nov.loc[tmp,'user_session'] = '9da8c2c7-5191-4124-9907-83440198093a'

# 결과 확인
df_nov[df_nov.user_id==570411102].reset_index().drop('index', axis=1)
# Out:
#                  event_time event_type  product_id  \
# 0   2019-11-12 05:23:48 UTC       view     4804391
# 1   2019-11-12 05:23:53 UTC       view     4804082
# 2   2019-11-12 05:24:43 UTC       view     4803738
# 3   2019-11-12 05:26:10 UTC       view     4803580
# 4   2019-11-12 05:34:11 UTC       view     4802255
# 5   2019-11-12 05:36:34 UTC       view     4803578
# 6   2019-11-12 05:36:46 UTC       view     4803580
# 7   2019-11-12 05:36:55 UTC       view     4803581
# 8   2019-11-12 05:37:07 UTC       view     4804322
# 9   2019-11-12 05:38:24 UTC       view     4804447
# 10  2019-11-12 05:39:10 UTC       view     4804322
# 11  2019-11-12 05:44:11 UTC       view     4802146
# 12  2019-11-12 05:45:36 UTC       view     4802146
# 13  2019-11-12 05:47:58 UTC       view     4800386
# 14  2019-11-12 05:49:26 UTC       view     4803614
# 15  2019-11-12 05:50:19 UTC       view     4804267
# 16  2019-11-12 05:50:28 UTC       view     4804008
# 17  2019-11-12 05:50:40 UTC       view     4802196
# 18  2019-11-12 05:50:51 UTC       view     4802254
# 19  2019-11-12 05:55:16 UTC       view     4803472
# 20  2019-11-12 05:56:00 UTC       view     4800045
# 21  2019-11-13 04:02:03 UTC       cart     4804008
#
#                   category_code           brand   price    user_id  \
# 0   electronics.audio.headphone            sony  200.52  570411102
# 1   electronics.audio.headphone             jbl  120.72  570411102
# 2   electronics.audio.headphone             jbl   84.76  570411102
# 3   electronics.audio.headphone     plantronics  141.55  570411102
# 4   electronics.audio.headphone        marshall  298.59  570411102
# 5   electronics.audio.headphone     plantronics  100.11  570411102
# 6   electronics.audio.headphone     plantronics  141.55  570411102
# 7   electronics.audio.headphone     plantronics  102.71  570411102
# 8   electronics.audio.headphone     plantronics  124.49  570411102
# 9   electronics.audio.headphone     plantronics  100.36  570411102
# 10  electronics.audio.headphone     plantronics  124.49  570411102
# 11  electronics.audio.headphone     plantronics  205.40  570411102
# 12  electronics.audio.headphone     plantronics  205.40  570411102
# 13  electronics.audio.headphone          xiaomi  154.42  570411102
# 14  electronics.audio.headphone        marshall  174.26  570411102
# 15  electronics.audio.headphone  audio-technica  205.67  570411102
# 16  electronics.audio.headphone         bluedio   97.81  570411102
# 17  electronics.audio.headphone            sony  193.03  570411102
# 18  electronics.audio.headphone        marshall  186.87  570411102
# 19  electronics.audio.headphone           beats  283.12  570411102
# 20  electronics.audio.headphone           beats  141.32  570411102
# 21  electronics.audio.headphone         bluedio   97.81  570411102
#
#                             user_session
# 0   302ec8bd-146a-4fc1-9cef-558abefd9b88
# 1   4b491cfb-4263-400a-b186-56a2f110c887
# 2   bf4fe70e-bf35-4d7d-8fba-c32636b2a113
# 3   63d431d4-7f59-45af-afed-c6956ba45da8
# 4   a38340d5-d188-49c2-a4ef-b1823a36bd54
# 5   a38340d5-d188-49c2-a4ef-b1823a36bd54
# 6   a38340d5-d188-49c2-a4ef-b1823a36bd54
# 7   a38340d5-d188-49c2-a4ef-b1823a36bd54
# 8   a38340d5-d188-49c2-a4ef-b1823a36bd54
# 9   a38340d5-d188-49c2-a4ef-b1823a36bd54
# 10  a38340d5-d188-49c2-a4ef-b1823a36bd54
# 11  a38340d5-d188-49c2-a4ef-b1823a36bd54
# 12  a38340d5-d188-49c2-a4ef-b1823a36bd54
# 13  a4a75492-6f21-442b-9b0f-42330c0b69a7
# 14  9da8c2c7-5191-4124-9907-83440198093a
# 15  81587d8c-1069-46da-a869-83aadd8b24ca
# 16  31f161ae-3ecb-41c6-8f55-b56d619dd873
# 17  b538a68c-7e2b-4f85-9b66-0a8a5b2f0de9
# 18  81a9be7e-3255-4a64-89ae-35481f85f7e0
# 19  9da8c2c7-5191-4124-9907-83440198093a
# 20  9da8c2c7-5191-4124-9907-83440198093a
# 21  9da8c2c7-5191-4124-9907-83440198093a

# %% [markdown]
# ### Nov. - Case 4

# %%
df_nov[df_nov.user_id==570878749].reset_index().drop('index', axis=1)
# Out:
#                 event_time event_type  product_id           category_code  \
# 0  2019-11-13 07:17:41 UTC       view     1004767  electronics.smartphone
# 1  2019-11-13 07:18:35 UTC       cart     1004767  electronics.smartphone
#
#      brand   price    user_id                          user_session
# 0  samsung  243.51  570878749  836c4aa8-e371-4033-82ab-b44b4de7ce5b
# 1  samsung  243.51  570878749                                  None

# %%
# index 값 추출하여 
tmp = df_nov[(df_nov.user_id==570878749) & (df_nov.user_session.isnull())].index[0]

# 바로 앞의(9번) user_session 값으로 대체
df_nov.loc[tmp,'user_session'] = '836c4aa8-e371-4033-82ab-b44b4de7ce5b'

# 결과 확인
df_nov[df_nov.user_id==570878749].reset_index().drop('index', axis=1)
# Out:
#                 event_time event_type  product_id           category_code  \
# 0  2019-11-13 07:17:41 UTC       view     1004767  electronics.smartphone
# 1  2019-11-13 07:18:35 UTC       cart     1004767  electronics.smartphone
#
#      brand   price    user_id                          user_session
# 0  samsung  243.51  570878749  836c4aa8-e371-4033-82ab-b44b4de7ce5b
# 1  samsung  243.51  570878749  836c4aa8-e371-4033-82ab-b44b4de7ce5b

# %% [markdown]
# ### Nov. - Case 5

# %%
df_nov[df_nov.user_id==575357602].reset_index().drop('index', axis=1)
# Out:
#                 event_time event_type  product_id category_code    brand  \
# 0  2019-11-23 09:52:02 UTC       view     7600251          None   d-link
# 1  2019-11-23 09:53:13 UTC       view     7600252          None  tp-link
# 2  2019-11-23 09:54:40 UTC       view     7600528          None  tp-link
# 3  2019-11-23 09:56:57 UTC       view     7600253          None   d-link
# 4  2019-11-23 09:58:47 UTC       view     7600323          None   d-link
# 5  2019-11-23 12:53:50 UTC       cart     7600528          None  tp-link
#
#    price    user_id                          user_session
# 0  15.93  575357602  cecc5635-dc3f-4496-bc77-9c403022161b
# 1  23.29  575357602  57fac5f8-cf77-4557-a135-9589e31ffc47
# 2  16.73  575357602  a052d1fc-5c27-44c7-964a-97808573d88d
# 3  20.81  575357602  0a9691f8-56db-4d5a-9e7e-f37f51767a43
# 4  23.02  575357602  bf6a8130-72f8-42e1-a7f0-9e904139b703
# 5  16.73  575357602                                  None

# %%
# index 값 추출하여 
tmp = df_nov[(df_nov.user_id==575357602) & (df_nov.user_session.isnull())].index[0]

# 바로 앞의(9번) user_session 값으로 대체
df_nov.loc[tmp,'user_session'] = 'bf6a8130-72f8-42e1-a7f0-9e904139b703'

# 결과 확인
df_nov[df_nov.user_id==575357602].reset_index().drop('index', axis=1)
# Out:
#                 event_time event_type  product_id category_code    brand  \
# 0  2019-11-23 09:52:02 UTC       view     7600251          None   d-link
# 1  2019-11-23 09:53:13 UTC       view     7600252          None  tp-link
# 2  2019-11-23 09:54:40 UTC       view     7600528          None  tp-link
# 3  2019-11-23 09:56:57 UTC       view     7600253          None   d-link
# 4  2019-11-23 09:58:47 UTC       view     7600323          None   d-link
# 5  2019-11-23 12:53:50 UTC       cart     7600528          None  tp-link
#
#    price    user_id                          user_session
# 0  15.93  575357602  cecc5635-dc3f-4496-bc77-9c403022161b
# 1  23.29  575357602  57fac5f8-cf77-4557-a135-9589e31ffc47
# 2  16.73  575357602  a052d1fc-5c27-44c7-964a-97808573d88d
# 3  20.81  575357602  0a9691f8-56db-4d5a-9e7e-f37f51767a43
# 4  23.02  575357602  bf6a8130-72f8-42e1-a7f0-9e904139b703
# 5  16.73  575357602  bf6a8130-72f8-42e1-a7f0-9e904139b703

# %% [markdown]
# ### Nov. - Case 6

# %%
df_nov[df_nov.user_id==573722572].reset_index().drop('index', axis=1)
# Out:
#                  event_time event_type  product_id           category_code  \
# 0   2019-11-20 03:30:19 UTC       view     1201216      electronics.tablet
# 1   2019-11-20 03:30:57 UTC       view     1201216      electronics.tablet
# 2   2019-11-20 03:31:37 UTC       view     1200965      electronics.tablet
# 3   2019-11-20 03:33:57 UTC       view     1200965      electronics.tablet
# 4   2019-11-20 03:39:56 UTC       view     1004741  electronics.smartphone
# 5   2019-11-20 03:40:08 UTC       view     1004741  electronics.smartphone
# 6   2019-11-20 03:40:58 UTC       view     1004741  electronics.smartphone
# 7   2019-11-20 03:41:06 UTC       cart     1004741  electronics.smartphone
# 8   2019-11-20 03:41:29 UTC       view     1004741  electronics.smartphone
# 9   2019-11-20 03:41:31 UTC       cart     1004741  electronics.smartphone
# 10  2019-11-21 04:59:17 UTC       view     1480492       computers.desktop
# 11  2019-11-21 04:59:52 UTC       view     1480492       computers.desktop
# 12  2019-11-21 05:00:37 UTC       view     1401129       computers.desktop
# 13  2019-11-21 05:01:23 UTC       view     1401129       computers.desktop
# 14  2019-11-21 05:01:48 UTC       view     1480690       computers.desktop
# 15  2019-11-21 05:02:25 UTC       view     1480690       computers.desktop
# 16  2019-11-21 05:02:51 UTC       view   100010164       computers.desktop
# 14     acer   257.38  573722572  eb840f9d-c19b-44b9-aeb3-a4a618c2b1f3
# 15     acer   257.38  573722572  eb840f9d-c19b-44b9-aeb3-a4a618c2b1f3
# 16   pulser   247.08  573722572  eb840f9d-c19b-44b9-aeb3-a4a618c2b1f3
# 17   pulser   247.08  573722572  eb840f9d-c19b-44b9-aeb3-a4a618c2b1f3
# 18    remix    75.97  573722572  eb840f9d-c19b-44b9-aeb3-a4a618c2b1f3
# 19       hp   334.37  573722572  eb840f9d-c19b-44b9-aeb3-a4a618c2b1f3
# 20       hp   334.37  573722572  eb840f9d-c19b-44b9-aeb3-a4a618c2b1f3
# 21  shivaki   154.42  573722572  1726d382-afab-418c-abfa-0373c6a026df
# 22  shivaki   154.42  573722572  1726d382-afab-418c-abfa-0373c6a026df
# 23  shivaki   154.42  573722572  1726d382-afab-418c-abfa-0373c6a026df
# 24  shivaki   257.66  573722572  7acfe63c-d3c6-4497-bc6a-ad879e77803e
# 25  shivaki   257.66  573722572  7acfe63c-d3c6-4497-bc6a-ad879e77803e
# 26  shivaki   257.66  573722572  7acfe63c-d3c6-4497-bc6a-ad879e77803e
# 27  shivaki   257.66  573722572  c2e3ae84-5a16-4d54-a99f-962b2a03e50b
# 28  shivaki   154.42  573722572  c2e3ae84-5a16-4d54-a99f-962b2a03e50b
# 29  shivaki   154.42  573722572  c2e3ae84-5a16-4d54-a99f-962b2a03e50b
# 30  shivaki   257.66  573722572  c2e3ae84-5a16-4d54-a99f-962b2a03e50b
# 31  shivaki   257.66  573722572  c2e3ae84-5a16-4d54-a99f-962b2a03e50b
# 32  samsung   386.08  573722572  194ed4ad-495c-4eb7-b21f-43cd97ffaabf
# 33      arg   360.09  573722572  194ed4ad-495c-4eb7-b21f-43cd97ffaabf
# 34      arg   360.09  573722572  3f51da10-109d-4036-9caa-d8e927082ab3
# 35      arg   360.09  573722572  d3835e60-b927-4ad8-bf21-fed6a905e84e
# 36      arg   360.09  573722572                                  None
# 37      arg   360.09  573722572  81382e85-bdb4-4edc-9b6c-1e109aa5677b
# 38      arg   360.09  573722572  81382e85-bdb4-4edc-9b6c-1e109aa5677b
# 39    artel   240.90  573722572  9e8f8e43-1696-4c15-8c25-18806523b969
# 40    artel   240.90  573722572  9e8f8e43-1696-4c15-8c25-18806523b969
# 41    artel   240.90  573722572  d303d681-57ae-42a7-91b8-395f884df1fb

# %%
# index 값 추출하여 
tmp = df_nov[(df_nov.user_id==573722572) & (df_nov.user_session.isnull())].index[0]

# 바로 앞의(9번) user_session 값으로 대체
df_nov.loc[tmp,'user_session'] = 'd3835e60-b927-4ad8-bf21-fed6a905e84e'

# 결과 확인
df_nov[df_nov.user_id==573722572].reset_index().drop('index', axis=1)
# Out:
#                  event_time event_type  product_id           category_code  \
# 0   2019-11-20 03:30:19 UTC       view     1201216      electronics.tablet
# 1   2019-11-20 03:30:57 UTC       view     1201216      electronics.tablet
# 2   2019-11-20 03:31:37 UTC       view     1200965      electronics.tablet
# 3   2019-11-20 03:33:57 UTC       view     1200965      electronics.tablet
# 38      arg   360.09  573722572  81382e85-bdb4-4edc-9b6c-1e109aa5677b
# 39    artel   240.90  573722572  9e8f8e43-1696-4c15-8c25-18806523b969
# 40    artel   240.90  573722572  9e8f8e43-1696-4c15-8c25-18806523b969
# 41    artel   240.90  573722572  d303d681-57ae-42a7-91b8-395f884df1fb

# %% [markdown]
# ### Nov. - Case 7

# %%
df_nov[df_nov.user_id==576301354].reset_index().drop('index', axis=1)
# Out:
#                 event_time event_type  product_id       category_code brand  \
# 0  2019-11-25 06:09:14 UTC       view    21404608  electronics.clocks  None
# 1  2019-11-25 06:14:54 UTC       view    21403753  electronics.clocks  None
# 2  2019-11-25 06:15:50 UTC       view    21404608  electronics.clocks  None
# 3  2019-11-25 06:16:16 UTC       view    21403753  electronics.clocks  None
# 4  2019-11-25 07:03:38 UTC       cart    21403753  electronics.clocks  None
#
#     price    user_id                          user_session
# 0  262.30  576301354  c38c005b-8cbc-4a21-ab3d-9763db74f932
# 1  181.47  576301354  c38c005b-8cbc-4a21-ab3d-9763db74f932
# 2  262.30  576301354  c38c005b-8cbc-4a21-ab3d-9763db74f932
# 3  181.47  576301354  c38c005b-8cbc-4a21-ab3d-9763db74f932
# 4  181.47  576301354                                  None

# %%
# index 값 추출하여 
tmp = df_nov[(df_nov.user_id==576301354) & (df_nov.user_session.isnull())].index[0]

# 바로 앞의(9번) user_session 값으로 대체
df_nov.loc[tmp,'user_session'] = 'c38c005b-8cbc-4a21-ab3d-9763db74f932'

# 결과 확인
df_nov[df_nov.user_id==576301354].reset_index().drop('index', axis=1)
# Out:
#                 event_time event_type  product_id       category_code brand  \
# 0  2019-11-25 06:09:14 UTC       view    21404608  electronics.clocks  None
# 1  2019-11-25 06:14:54 UTC       view    21403753  electronics.clocks  None
# 2  2019-11-25 06:15:50 UTC       view    21404608  electronics.clocks  None
# 3  2019-11-25 06:16:16 UTC       view    21403753  electronics.clocks  None
# 4  2019-11-25 07:03:38 UTC       cart    21403753  electronics.clocks  None
#
#     price    user_id                          user_session
# 0  262.30  576301354  c38c005b-8cbc-4a21-ab3d-9763db74f932
# 1  181.47  576301354  c38c005b-8cbc-4a21-ab3d-9763db74f932
# 2  262.30  576301354  c38c005b-8cbc-4a21-ab3d-9763db74f932
# 3  181.47  576301354  c38c005b-8cbc-4a21-ab3d-9763db74f932
# 4  181.47  576301354  c38c005b-8cbc-4a21-ab3d-9763db74f932

# %% [markdown]
# ### Nov. - Case 8

# %%
df_nov[df_nov.user_id==576935861].reset_index().drop('index', axis=1)
# Out:
#                 event_time event_type  product_id  \
# 0  2019-11-26 07:47:29 UTC       view     4804718
# 1  2019-11-26 07:48:12 UTC       cart     4804718
# 2  2019-11-29 13:31:39 UTC       view     1004659
#
#                  category_code    brand   price    user_id  \
# 0  electronics.audio.headphone    apple  334.58  576935861
# 1  electronics.audio.headphone    apple  334.58  576935861
# 2       electronics.smartphone  samsung  738.35  576935861
#
#                            user_session
# 0  5ac42010-7cb2-4151-b4d4-840fbd5c3102
# 1                                  None
# 2  670cd99b-3c5b-42f7-9b97-5f0520dc561a

# %%
# index 값 추출하여 
tmp = df_nov[(df_nov.user_id==576935861) & (df_nov.user_session.isnull())].index[0]

# 바로 앞의(9번) user_session 값으로 대체
df_nov.loc[tmp,'user_session'] = '5ac42010-7cb2-4151-b4d4-840fbd5c3102'

# 결과 확인
df_nov[df_nov.user_id==576935861].reset_index().drop('index', axis=1)
# Out:
#                 event_time event_type  product_id  \
# 0  2019-11-26 07:47:29 UTC       view     4804718
# 1  2019-11-26 07:48:12 UTC       cart     4804718
# 2  2019-11-29 13:31:39 UTC       view     1004659
#
#                  category_code    brand   price    user_id  \
# 0  electronics.audio.headphone    apple  334.58  576935861
# 1  electronics.audio.headphone    apple  334.58  576935861
# 2       electronics.smartphone  samsung  738.35  576935861
#
#                            user_session
# 0  5ac42010-7cb2-4151-b4d4-840fbd5c3102
# 1  5ac42010-7cb2-4151-b4d4-840fbd5c3102
# 2  670cd99b-3c5b-42f7-9b97-5f0520dc561a

# %% [markdown]
# ### Nov. - Case 9

# %%
df_nov[df_nov.user_id==577167045].reset_index().drop('index', axis=1)
# Out:
#                  event_time event_type  product_id category_code      brand  \
# 0   2019-11-26 15:46:37 UTC       view    12709269          None   triangle
# 1   2019-11-26 15:46:59 UTC       view    12709269          None   triangle
# 2   2019-11-26 15:47:26 UTC       view    12719553          None       None
# 3   2019-11-26 15:48:58 UTC       view    12717696          None    pirelli
# 4   2019-11-26 15:49:38 UTC       view   100000237          None  roadmarch
# 5   2019-11-26 15:49:56 UTC       view    12720098          None      roadx
# 6   2019-11-26 15:50:20 UTC       view    12719553          None       None
# 7   2019-11-26 15:50:32 UTC       cart    12719553          None       None
# 8   2019-11-26 15:59:14 UTC       view    12719553          None       None
# 9   2019-11-26 15:59:24 UTC       view    12719553          None       None
# 10  2019-11-26 15:59:36 UTC       view    12719553          None       None
# 11  2019-11-26 15:59:51 UTC       view    12719553          None       None
# 12  2019-11-26 16:00:05 UTC       view    12716715          None     kapsen
# 13  2019-11-26 16:00:20 UTC       view    12716715          None     kapsen
# 14  2019-11-26 16:00:28 UTC       view    12701423          None       None
# 15  2019-11-26 16:00:50 UTC       view    12718244          None  comforser
# 16  2019-11-26 16:01:02 UTC       view    12718244          None  comforser
# 17  2019-11-26 16:01:10 UTC       view    12701425          None       None
# 18  2019-11-26 16:01:31 UTC       view    12701425          None       None
# 19  2019-11-26 16:01:54 UTC       view    12718948          None       None
# 20  2019-11-26 16:02:08 UTC       view    12719933          None   achilles
# 21  2019-11-26 16:02:23 UTC       view    12705253          None     viatti
# 22  2019-11-26 16:02:38 UTC       view    12716707          None     kapsen
# 23  2019-11-26 16:03:02 UTC       view    12719553          None       None
# 24  2019-11-27 07:01:58 UTC       view    12719553          None       None
# 25  2019-11-27 07:02:20 UTC       cart    12719553          None       None
#
#     price    user_id                          user_session
# 0   55.34  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 1   55.34  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 2   55.60  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 3   72.72  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 4   56.55  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 5   48.91  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 6   55.60  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 7   55.60  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 8   55.60  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 9   55.60  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 10  55.60  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 11  55.60  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 12  55.86  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 13  55.86  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 14  55.86  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 15  56.63  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 16  56.63  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 17  58.43  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 18  58.43  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 19  61.28  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 20  61.78  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 21  56.63  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 22  63.04  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 23  55.60  577167045  71c1ca1d-c087-43bb-a9a5-785fc557bfc3
# 24  55.60  577167045  1dcf3c18-66e7-4a23-8e55-1ab390258607
# 25  55.60  577167045                                  None

# %%
# index 값 추출하여 
tmp = df_nov[(df_nov.user_id==577167045) & (df_nov.user_session.isnull())].index[0]

# 바로 앞의(9번) user_session 값으로 대체
df_nov.loc[tmp,'user_session'] = '1dcf3c18-66e7-4a23-8e55-1ab390258607'

# 결과 확인
df_nov[df_nov.user_id==577167045].reset_index().drop('index', axis=1)
# Out:
#                  event_time event_type  product_id category_code      brand  \
# 0   2019-11-26 15:46:37 UTC       view    12709269          None   triangle
# 1   2019-11-26 15:46:59 UTC       view    12709269          None   triangle
# 2   2019-11-26 15:47:26 UTC       view    12719553          None       None
# 3   2019-11-26 15:48:58 UTC       view    12717696          None    pirelli
# 4   2019-11-26 15:49:38 UTC       view   100000237          None  roadmarch
# 5   2019-11-26 15:49:56 UTC       view    12720098          None      roadx
# 6   2019-11-26 15:50:20 UTC       view    12719553          None       None
# 7   2019-11-26 15:50:32 UTC       cart    12719553          None       None
# 8   2019-11-26 15:59:14 UTC       view    12719553          None       None
# 9   2019-11-26 15:59:24 UTC       view    12719553          None       None
# 10  2019-11-26 15:59:36 UTC       view    12719553          None       None
# 11  2019-11-26 15:59:51 UTC       view    12719553          None       None
# %% [markdown]
# ### Nov. - Case 10

# %%
df_nov[df_nov.user_id==579123407].reset_index().drop('index', axis=1)
# Out:
#                 event_time event_type  product_id           category_code  \
# 0  2019-11-29 17:21:54 UTC       view     1005116  electronics.smartphone
# 1  2019-11-29 17:25:56 UTC       cart     1005116  electronics.smartphone
#
#    brand    price    user_id                          user_session
# 0  apple  1001.42  579123407  a8d85676-92e4-457c-b705-69e907217ca6
# 1  apple  1001.42  579123407                                  None

# %%
# index 값 추출하여 
tmp = df_nov[(df_nov.user_id==579123407) & (df_nov.user_session.isnull())].index[0]

# 바로 앞의(9번) user_session 값으로 대체
df_nov.loc[tmp,'user_session'] = 'a8d85676-92e4-457c-b705-69e907217ca6'

# 결과 확인
df_nov[df_nov.user_id==579123407].reset_index().drop('index', axis=1)
# Out:
#                 event_time event_type  product_id           category_code  \
# 0  2019-11-29 17:21:54 UTC       view     1005116  electronics.smartphone
# 1  2019-11-29 17:25:56 UTC       cart     1005116  electronics.smartphone
#
#    brand    price    user_id                          user_session
# 0  apple  1001.42  579123407  a8d85676-92e4-457c-b705-69e907217ca6
# 1  apple  1001.42  579123407  a8d85676-92e4-457c-b705-69e907217ca6

# %% [markdown]
# ### category_code, brand

# %% [markdown]
# - 2019.10~11

# %%
df_oct = df_oct.fillna('unknown')
df_nov = df_nov.fillna('unknown')

# %%
df_oct.isnull().sum()
# Out:
# event_time       0
# event_type       0
# product_id       0
# category_code    0
# brand            0
# price            0
# user_id          0
# user_session     0
# dtype: int64

# %%
df_nov.isnull().sum()
# Out:
# event_time       0
# event_type       0
# product_id       0
# category_code    0
# brand            0
# price            0
# user_id          0
# user_session     0
# dtype: int64

# %% [markdown]
# - 2019.12~2020.4

# %%
df_dec.isnull().sum()
# Out:
# event_time             0
# event_type             0
# category_code    7088848
# user_id                0
# dtype: int64

# %%
df_dec = df_dec.fillna('unknown')
df_jan = df_jan.fillna('unknown')
df_feb = df_feb.fillna('unknown')
df_mar = df_mar.fillna('unknown')
df_apr = df_apr.fillna('unknown')

# %% [markdown]
# ## Change dtypes
# 1. `event_time` : datetime 형태로 변경
# 2. 불필요한 메모리 축소
#   1. `event_type`, `category_code`, `brand`, `user_session` : object -> category
#     - (주의) 카테고리 변환이후 카테고리 수정시 에러발생,
#     - object 형태에서 모든 전처리 후 형변환 진행할 것
#   2. `product_id`, `user_id` : int64 -> int32
#   3. `price` : float64 -> float32

# %%
df_oct.dtypes   # 컬럼별 type 확인하기
# Out:
# event_time        object
# event_type        object
# product_id         int64
# category_code     object
# brand             object
# price            float64
# user_id            int64
# user_session      object
# dtype: object

# %%
df_nov.dtypes
# Out:
# event_time        object
# event_type        object
# product_id         int64
# category_code     object
# brand             object
# price            float64
# user_id            int64
# user_session      object
# dtype: object

# %%
# %time
# 1. datetime 형변환
df_oct['event_time'] = pd.to_datetime(df_oct['event_time'], format = '%Y-%m-%d %H:%M:%S UTC')
df_nov['event_time'] = pd.to_datetime(df_nov['event_time'], format = '%Y-%m-%d %H:%M:%S UTC')
# Out:
# Wall time: 0 ns

# %%
# %%time
# 2. 기타 형변환
# category 변환
df_oct[['event_type','category_code','brand','user_session']] = df_oct[['event_type','category_code','brand','user_session']].astype('category')
df_nov[['event_type','category_code','brand','user_session']] = df_nov[['event_type','category_code','brand','user_session']].astype('category')

# int 변환
df_oct[['product_id','user_id']] = df_oct[['product_id','user_id']].astype('int32')
df_nov[['product_id','user_id']] = df_nov[['product_id','user_id']].astype('int32')

# float 변환
df_oct['price'] = df_oct['price'].astype('float32')
df_nov['price'] = df_nov['price'].astype('float32')
# Out:
# Wall time: 3min 19s

# %%
df_oct.dtypes
# Out:
# event_time       datetime64[ns]
# event_type             category
# product_id                int32
# category_code          category
# brand                  category
# price                   float32
# user_id                   int32
# user_session           category
# dtype: object

# %%
df_nov.dtypes
# Out:
# event_time       datetime64[ns]
# event_type             category
# product_id                int32
# category_code          category
# brand                  category
# price                   float32
# user_id                   int32
# user_session           category
# dtype: object

# %% [markdown]
# -2019년 12월~2020년 4월

# %%
df_dec.dtypes
# Out:
# event_time        object
# event_type        object
# category_code     object
# price            float64
# user_id            int64
# dtype: object

# %%
def cleaning_dtypes(df):
    # 1. datetime 형변환
    df['event_time'] = pd.to_datetime(df['event_time'], format = '%Y-%m-%d %H:%M:%S UTC')
    
    # 2. 기타 형변환
    # category 변환
    df[['event_type','category_code']] = df[['event_type','category_code']].astype('category')

    # int 변환
    df[['user_id']] = df[['user_id']].astype('int32')
    
    # float 변환
    df['price'] = df['price'].astype('float32')
    
    
    return df

# %%
# %%time
cleaning_dtypes(df_dec)
# Out:
# Wall time: 31.4 s
#                   event_time event_type                  category_code  \
# 0        2019-12-01 00:00:00       view       construction.tools.light
# 1        2019-12-01 00:00:00       view                        unknown
# 2        2019-12-01 00:00:01       view   appliances.personal.massager
# 3        2019-12-01 00:00:02   purchase  computers.peripherals.printer
# 4        2019-12-01 00:00:02       view               apparel.trousers
# ...                      ...        ...                            ...
# 67542873 2019-12-31 23:59:58       view       construction.tools.light
# 67542874 2019-12-31 23:59:58       view    electronics.audio.headphone
# 67542875 2019-12-31 23:59:59       view                     kids.dolls
# 67542876 2019-12-31 23:59:59       view                  sport.bicycle
# 67542877 2019-12-31 23:59:59       view       construction.tools.light
#
#                 price    user_id
# 0         1302.479980  556695836
# 1          102.959999  577702456
# 2          313.519989  539453785
# 3          132.309998  535135317
# 4          101.680000  517987650
# ...               ...        ...
# 67542873   908.799988  515771654
# 67542874  1044.250000  595160289
# 67542875   411.829987  526621231
# 67542876    17.990000  574723072
# 67542877  1276.760010  595117926
#
# [67542878 rows x 5 columns]

# %%
cleaning_dtypes(df_jan)
# Out:
#                   event_time event_type              category_code  \
# 0        2020-01-01 00:00:00       view   construction.tools.light
# 1        2020-01-01 00:00:01       view   construction.tools.light
# 2        2020-01-01 00:00:01       view              apparel.shirt
# 3        2020-01-01 00:00:01       view              apparel.shoes
# 4        2020-01-01 00:00:02       view     apparel.shoes.step_ins
# ...                      ...        ...                        ...
# 55967036 2020-01-31 23:59:59       view              apparel.shoes
# 55967037 2020-01-31 23:59:59       view   construction.tools.light
# 55967038 2020-01-31 23:59:59       view              apparel.shoes
# 55967039 2020-01-31 23:59:59       view  furniture.bedroom.blanket
# 55967040 2020-01-31 23:59:59       view   construction.tools.light
#
#                 price    user_id
# 0         1130.020020  519698804
# 1          205.669998  527767423
# 2          136.429993  519046195
# 3           29.950001  518269232
# 4          167.199997  587748686
# ...               ...        ...
# 55967036    33.720001  517548219
# 55967037   228.830002  512985520
# 55967038    47.360001  513043451
# 55967039    51.299999  581011571
# 55967040   230.250000  554528253
#
# [55967041 rows x 5 columns]

# %%
cleaning_dtypes(df_feb)
# Out:
#                   event_time event_type                     category_code  \
# 0        2020-02-01 00:00:00       view                     apparel.shoes
# 1        2020-02-01 00:00:00       view                     sport.bicycle
# 2        2020-02-01 00:00:00       view          construction.tools.light
# 3        2020-02-01 00:00:01       view          construction.tools.light
# 4        2020-02-01 00:00:01       view  appliances.kitchen.refrigerators
# ...                      ...        ...                               ...
# 55318560 2020-02-29 23:59:57       view        construction.tools.welding
# 55318561 2020-02-29 23:59:58       view         appliances.kitchen.toster
# 55318562 2020-02-29 23:59:58       view             electronics.telephone
# 55318563 2020-02-29 23:59:59       view          electronics.camera.video
# 55318564 2020-02-29 23:59:59       view                   accessories.bag
#
#                price    user_id
# 0          19.309999  581521975
# 1          11.880000  596313635
# 2         838.229980  608821035
# 3         410.420013  530488542
# 4         332.029999  583795643
# ...              ...        ...
# 55318560    1.930000  519011545
# 55318561   77.199997  540823940
# 55318562   49.910000  531574188
# 55318563   10.770000  614934914
# 55318564  129.190002  622090611
#
# [55318565 rows x 5 columns]

# %%
cleaning_dtypes(df_mar)
# Out:
#                   event_time event_type                 category_code  \
# 0        2020-03-01 00:00:00       view      appliances.kitchen.mixer
# 1        2020-03-01 00:00:01       view             apparel.underwear
# 2        2020-03-01 00:00:03       view         furniture.bedroom.bed
# 3        2020-03-01 00:00:03       view  construction.tools.generator
# 4        2020-03-01 00:00:04       view      construction.tools.light
# ...                      ...        ...                           ...
# 56341236 2020-03-31 23:59:55       view      construction.tools.light
# 56341237 2020-03-31 23:59:55       view  appliances.personal.massager
# 56341238 2020-03-31 23:59:56       view                       unknown
# 56341239 2020-03-31 23:59:56       view  appliances.personal.massager
# 56341240 2020-03-31 23:59:57       view                       unknown
#
#                price    user_id
# 0         117.629997  550295099
# 1         264.369995  622070532
# 2         126.099998  552832344
# 3         424.720001  613391860
# 4         482.730011  517021211
# ...              ...        ...
# 56341236  178.119995  516506125
# 56341237  154.419998  572260610
# 56341238  167.289993  523607693
# 56341239  163.160004  629229484
# 56341240   85.949997  513238692
#
# [56341241 rows x 5 columns]

# %%
cleaning_dtypes(df_apr)
# Out:
#                   event_time event_type                     category_code  \
# 0        2020-04-01 00:00:00       view             apparel.shoes.slipons
# 1        2020-04-01 00:00:01       view       electronics.audio.headphone
# 2        2020-04-01 00:00:01       view  appliances.kitchen.refrigerators
# 3        2020-04-01 00:00:02       view       electronics.audio.headphone
# 4        2020-04-01 00:00:03       view                     apparel.scarf
# ...                      ...        ...                               ...
# 66589263 2020-04-30 23:59:59       view          construction.tools.light
# 66589264 2020-04-30 23:59:59       view          construction.tools.light
# 66589265 2020-04-30 23:59:59       view                     apparel.shirt
# 66589266 2020-04-30 23:59:59       view         appliances.kitchen.toster
# 66589267 2020-04-30 23:59:59       view          construction.tools.light
#
#                 price    user_id
# 0          230.380005  568984877
# 1         1352.670044  514955500
# 2         1184.050049  633645770
# 3         1724.339966  564933778
# 4           25.049999  530206135
# ...               ...        ...
# 66589263   900.900024  648021639
# 66589264  1599.780029  649775363
# 66589265    12.840000  639250275
# 66589266  1956.030029  522762529
# 66589267   228.830002  530264277
#
# [66589268 rows x 5 columns]

# %% [markdown]
# ## event_time 관련 특성공학
# - GMT+6(카자흐스탄으로 가정)
# - 년월일, 월, 일, 요일, 시간, 주차 특성 생성

# %%
# 10월
df_oct['event_time'].head()
# Out:
# 0   2019-10-01 00:00:00
# 1   2019-10-01 00:00:00
# 2   2019-10-01 00:00:01
# 3   2019-10-01 00:00:01
# 4   2019-10-01 00:00:04
# Name: event_time, dtype: datetime64[ns]

# %%
# timedelta로 전체 시간 +6
df_oct['event_time'] = pd.DatetimeIndex(df_oct['event_time']) + timedelta(hours=6)
df_oct['event_time']
# Out:
# 0          2019-10-01 06:00:00
# 1          2019-10-01 06:00:00
# 2          2019-10-01 06:00:01
# 3          2019-10-01 06:00:01
# 4          2019-10-01 06:00:04
#                    ...
# 42448759   2019-11-01 05:59:58
# 42448760   2019-11-01 05:59:58
# 42448761   2019-11-01 05:59:58
# 42448762   2019-11-01 05:59:59
# 42448763   2019-11-01 05:59:59
# Name: event_time, Length: 42448764, dtype: datetime64[ns]

# %%
# 11월
df_nov['event_time'].head()
# Out:
# 0   2019-11-01 00:00:00
# 1   2019-11-01 00:00:00
# 2   2019-11-01 00:00:01
# 3   2019-11-01 00:00:01
# 4   2019-11-01 00:00:01
# Name: event_time, dtype: datetime64[ns]

# %%
# timedelta로 전체 시간 +6 
df_nov['event_time'] = pd.DatetimeIndex(df_nov['event_time']) + timedelta(hours=6)
df_nov['event_time']
# Out:
# 0          2019-11-01 06:00:00
# 1          2019-11-01 06:00:00
# 2          2019-11-01 06:00:01
# 3          2019-11-01 06:00:01
# 4          2019-11-01 06:00:01
#                    ...
# 67501974   2019-12-01 05:59:58
# 67501975   2019-12-01 05:59:58
# 67501976   2019-12-01 05:59:59
# 67501977   2019-12-01 05:59:59
# 67501978   2019-12-01 05:59:59
# Name: event_time, Length: 67501979, dtype: datetime64[ns]

# %%
# %%time
# 날짜만 별도로 추출
df_oct['event_date'] = pd.DatetimeIndex(df_oct['event_time']).date
df_nov['event_date'] = pd.DatetimeIndex(df_nov['event_time']).date
df_oct.head(1)
# Out:
# Wall time: 35.6 s
#            event_time event_type  product_id category_code     brand  \
# 0 2019-10-01 06:00:00       view    44600062       unknown  shiseido
#
#        price    user_id                          user_session  event_date
# 0  35.790001  541312140  72d76fde-8bb3-4e00-8c23-a032dfed738c  2019-10-01

# %%
# %%time
# 월 컬럼 생성
df_oct['event_month'] = df_oct['event_time'].dt.month
df_nov['event_month'] = df_nov['event_time'].dt.month
df_oct.head(1)
# Out:
# Wall time: 9.36 s
#            event_time event_type  product_id category_code     brand  \
# 0 2019-10-01 06:00:00       view    44600062       unknown  shiseido
#
#        price    user_id                          user_session  event_date  \
# 0  35.790001  541312140  72d76fde-8bb3-4e00-8c23-a032dfed738c  2019-10-01
#
#    event_month
# 0           10

# %%
# %%time
# 일 컬럼 생성
df_oct['event_day'] = df_oct['event_time'].dt.day
df_nov['event_day'] = df_nov['event_time'].dt.day
df_oct.head(1)
# Out:
# Wall time: 11.3 s
#            event_time event_type  product_id category_code     brand  \
# 0 2019-10-01 06:00:00       view    44600062       unknown  shiseido
#
#        price    user_id                          user_session  event_date  \
# 0  35.790001  541312140  72d76fde-8bb3-4e00-8c23-a032dfed738c  2019-10-01
#
#    event_month  event_day
# 0           10          1

# %%
# %%time
# 요일 생성
df_oct['day_of_week'] = df_oct['event_time'].dt.day_name()
df_nov['day_of_week'] = df_nov['event_time'].dt.day_name()
df_oct.head(1)
# Out:
# Wall time: 45.2 s
#            event_time event_type  product_id category_code     brand  \
# 0 2019-10-01 06:00:00       view    44600062       unknown  shiseido
#
#        price    user_id                          user_session  event_date  \
# 0  35.790001  541312140  72d76fde-8bb3-4e00-8c23-a032dfed738c  2019-10-01
#
#    event_month  event_day day_of_week
# 0           10          1     Tuesday

# %%
# %%time
# 시 생성
df_oct['event_hour'] = df_oct['event_time'].dt.hour
df_nov['event_hour'] = df_nov['event_time'].dt.hour
df_oct.head(1)
# Out:
# Wall time: 10.3 s
#            event_time event_type  product_id category_code     brand  \
# 0 2019-10-01 06:00:00       view    44600062       unknown  shiseido
#
#        price    user_id                          user_session  event_date  \
# 0  35.790001  541312140  72d76fde-8bb3-4e00-8c23-a032dfed738c  2019-10-01
#
#    event_month  event_day day_of_week  event_hour
# 0           10          1     Tuesday           6

# %%
# %%time
# 주차 컬럼 생성
df_oct['event_week'] = df_oct['event_time'].dt.isocalendar()['week']
df_nov['event_week'] = df_nov['event_time'].dt.isocalendar()['week']
df_oct.head(1)
# Out:
# Wall time: 28.9 s
#            event_time event_type  product_id category_code     brand  \
# 0 2019-10-01 06:00:00       view    44600062       unknown  shiseido
#
#        price    user_id                          user_session  event_date  \
# 0  35.790001  541312140  72d76fde-8bb3-4e00-8c23-a032dfed738c  2019-10-01
#
#    event_month  event_day day_of_week  event_hour  event_week
# 0           10          1     Tuesday           6          40

# %%
df_oct.dtypes
# Out:
# event_time       datetime64[ns]
# event_type             category
# product_id                int32
# category_code          category
# brand                  category
# price                   float32
# user_id                   int32
# user_session           category
# event_date               object
# event_month               int64
# event_day                 int64
# day_of_week              object
# event_hour                int64
# event_week               UInt32
# dtype: object

# %%
# %%time
# 추가된 열의 형변환
# category 변환 - 요일
df_oct['day_of_week'] = df_oct['day_of_week'].astype('category')
df_nov['day_of_week'] = df_nov['day_of_week'].astype('category')

# # int32 변환
df_oct[['event_month','event_day','event_hour']] = df_oct[['event_month','event_day','event_hour']].astype('int32')
df_nov[['event_month','event_day','event_hour']] = df_nov[['event_month','event_day','event_hour']].astype('int32')
# Out:
# Wall time: 24.8 s

# %%
df_oct.dtypes
# Out:
# event_time       datetime64[ns]
# event_type             category
# product_id                int32
# category_code          category
# brand                  category
# price                   float32
# user_id                   int32
# user_session           category
# event_date               object
# event_month               int32
# event_day                 int32
# day_of_week            category
# event_hour                int32
# event_week               UInt32
# dtype: object

# %% [markdown]
# - 12월 ~4월

# %%
def cleaning_time(df):
    # 시간대 +6 (카자흐스탄 시간으로 바꿔주기)
    df['event_time'] = pd.DatetimeIndex(df['event_time']) + timedelta(hours=6)
    
    # 날짜만 별도로 추출
    df['event_date'] = pd.DatetimeIndex(df['event_time']).date
        
    # 월 컬럼 생성
    df['event_month'] = df['event_time'].dt.month
    
    # 주차 컬럼 생성
    df['event_week'] = df['event_time'].dt.isocalendar()['week']
    
    return df

# %%
# %%time
# 자꾸 ram 부족 터져서 한 줄에 하나씩
# 전처리 진행
cleaning_time(df_dec)
# Out:
# Wall time: 33.7 s
#                   event_time event_type                  category_code  \
# 0        2019-12-01 06:00:00       view       construction.tools.light
# 1        2019-12-01 06:00:00       view                        unknown
# 2        2019-12-01 06:00:01       view   appliances.personal.massager
# 3        2019-12-01 06:00:02   purchase  computers.peripherals.printer
# 4        2019-12-01 06:00:02       view               apparel.trousers
# ...                      ...        ...                            ...
# 67542873 2020-01-01 05:59:58       view       construction.tools.light
# 67542874 2020-01-01 05:59:58       view    electronics.audio.headphone
# 67542875 2020-01-01 05:59:59       view                     kids.dolls
# 67542876 2020-01-01 05:59:59       view                  sport.bicycle
# 67542877 2020-01-01 05:59:59       view       construction.tools.light
#
#                 price    user_id  event_date  event_month  event_week
# 0         1302.479980  556695836  2019-12-01           12          48
# 1          102.959999  577702456  2019-12-01           12          48
# 2          313.519989  539453785  2019-12-01           12          48
# 3          132.309998  535135317  2019-12-01           12          48
# 4          101.680000  517987650  2019-12-01           12          48
# ...               ...        ...         ...          ...         ...
# 67542873   908.799988  515771654  2020-01-01            1           1
# 67542874  1044.250000  595160289  2020-01-01            1           1
# 67542875   411.829987  526621231  2020-01-01            1           1
# 67542876    17.990000  574723072  2020-01-01            1           1
# 67542877  1276.760010  595117926  2020-01-01            1           1
#
# [67542878 rows x 8 columns]

# %%
cleaning_time(df_jan)
# Out:
#                   event_time event_type              category_code  \
# 0        2020-01-01 06:00:00       view   construction.tools.light
# 1        2020-01-01 06:00:01       view   construction.tools.light
# 2        2020-01-01 06:00:01       view              apparel.shirt
# 3        2020-01-01 06:00:01       view              apparel.shoes
# 4        2020-01-01 06:00:02       view     apparel.shoes.step_ins
# ...                      ...        ...                        ...
# 55967036 2020-02-01 05:59:59       view              apparel.shoes
# 55967037 2020-02-01 05:59:59       view   construction.tools.light
# 55967038 2020-02-01 05:59:59       view              apparel.shoes
# 55967039 2020-02-01 05:59:59       view  furniture.bedroom.blanket
# 55967040 2020-02-01 05:59:59       view   construction.tools.light
#
#                 price    user_id  event_date  event_month  event_week
# 0         1130.020020  519698804  2020-01-01            1           1
# 1          205.669998  527767423  2020-01-01            1           1
# 2          136.429993  519046195  2020-01-01            1           1
# 3           29.950001  518269232  2020-01-01            1           1
# 4          167.199997  587748686  2020-01-01            1           1
# ...               ...        ...         ...          ...         ...
# 55967036    33.720001  517548219  2020-02-01            2           5
# 55967037   228.830002  512985520  2020-02-01            2           5
# 55967038    47.360001  513043451  2020-02-01            2           5
# 55967039    51.299999  581011571  2020-02-01            2           5
# 55967040   230.250000  554528253  2020-02-01            2           5
#
# [55967041 rows x 8 columns]

# %%
cleaning_time(df_feb)
# Out:
#                   event_time event_type                     category_code  \
# 0        2020-02-01 06:00:00       view                     apparel.shoes
# 1        2020-02-01 06:00:00       view                     sport.bicycle
# 2        2020-02-01 06:00:00       view          construction.tools.light
# 3        2020-02-01 06:00:01       view          construction.tools.light
# 4        2020-02-01 06:00:01       view  appliances.kitchen.refrigerators
# ...                      ...        ...                               ...
# 55318560 2020-03-01 05:59:57       view        construction.tools.welding
# 55318561 2020-03-01 05:59:58       view         appliances.kitchen.toster
# 55318562 2020-03-01 05:59:58       view             electronics.telephone
# 55318563 2020-03-01 05:59:59       view          electronics.camera.video
# 55318564 2020-03-01 05:59:59       view                   accessories.bag
#
#                price    user_id  event_date  event_month  event_week
# 0          19.309999  581521975  2020-02-01            2           5
# 1          11.880000  596313635  2020-02-01            2           5
# 2         838.229980  608821035  2020-02-01            2           5
# 3         410.420013  530488542  2020-02-01            2           5
# 4         332.029999  583795643  2020-02-01            2           5
# ...              ...        ...         ...          ...         ...
# 55318560    1.930000  519011545  2020-03-01            3           9
# 55318561   77.199997  540823940  2020-03-01            3           9
# 55318562   49.910000  531574188  2020-03-01            3           9
# 55318563   10.770000  614934914  2020-03-01            3           9
# 55318564  129.190002  622090611  2020-03-01            3           9
#
# [55318565 rows x 8 columns]

# %%
cleaning_time(df_mar)
# Out:
#                   event_time event_type                 category_code  \
# 0        2020-03-01 06:00:00       view      appliances.kitchen.mixer
# 1        2020-03-01 06:00:01       view             apparel.underwear
# 2        2020-03-01 06:00:03       view         furniture.bedroom.bed
# 3        2020-03-01 06:00:03       view  construction.tools.generator
# 4        2020-03-01 06:00:04       view      construction.tools.light
# ...                      ...        ...                           ...
# 56341236 2020-04-01 05:59:55       view      construction.tools.light
# 56341237 2020-04-01 05:59:55       view  appliances.personal.massager
# 56341238 2020-04-01 05:59:56       view                       unknown
# 56341239 2020-04-01 05:59:56       view  appliances.personal.massager
# 56341240 2020-04-01 05:59:57       view                       unknown
#
#                price    user_id  event_date  event_month  event_week
# 0         117.629997  550295099  2020-03-01            3           9
# 1         264.369995  622070532  2020-03-01            3           9
# 2         126.099998  552832344  2020-03-01            3           9
# 3         424.720001  613391860  2020-03-01            3           9
# 4         482.730011  517021211  2020-03-01            3           9
# ...              ...        ...         ...          ...         ...
# 56341236  178.119995  516506125  2020-04-01            4          14
# 56341237  154.419998  572260610  2020-04-01            4          14
# 56341238  167.289993  523607693  2020-04-01            4          14
# 56341239  163.160004  629229484  2020-04-01            4          14
# 56341240   85.949997  513238692  2020-04-01            4          14
#
# [56341241 rows x 8 columns]

# %%
cleaning_time(df_apr)
# Out:
#                   event_time event_type                     category_code  \
# 0        2020-04-01 06:00:00       view             apparel.shoes.slipons
# 1        2020-04-01 06:00:01       view       electronics.audio.headphone
# 2        2020-04-01 06:00:01       view  appliances.kitchen.refrigerators
# 3        2020-04-01 06:00:02       view       electronics.audio.headphone
# 4        2020-04-01 06:00:03       view                     apparel.scarf
# ...                      ...        ...                               ...
# 66589263 2020-05-01 05:59:59       view          construction.tools.light
# 66589264 2020-05-01 05:59:59       view          construction.tools.light
# 66589265 2020-05-01 05:59:59       view                     apparel.shirt
# 66589266 2020-05-01 05:59:59       view         appliances.kitchen.toster
# 66589267 2020-05-01 05:59:59       view          construction.tools.light
#
#                 price    user_id  event_date  event_month  event_week
# 0          230.380005  568984877  2020-04-01            4          14
# 1         1352.670044  514955500  2020-04-01            4          14
# 2         1184.050049  633645770  2020-04-01            4          14
# 3         1724.339966  564933778  2020-04-01            4          14
# 4           25.049999  530206135  2020-04-01            4          14
# ...               ...        ...         ...          ...         ...
# 66589263   900.900024  648021639  2020-05-01            5          18
# 66589264  1599.780029  649775363  2020-05-01            5          18
# 66589265    12.840000  639250275  2020-05-01            5          18
# 66589266  1956.030029  522762529  2020-05-01            5          18
# 66589267   228.830002  530264277  2020-05-01            5          18
#
# [66589268 rows x 8 columns]

# %% [markdown]
# ## 10월 끝에 11월 1~3일 데이터 붙이기
# - 10월 4주차 데이터 확보 위해서 (11월 초반)

# %%
# tmp변수에 11월 1일,2일,3일 데이터 지정
tmp = df_nov[(df_nov['event_time'] < '2019-11-04')]
tmp
# Out:
#                  event_time event_type  product_id              category_code  \
# 0       2019-11-01 06:00:00       view     1003461     electronics.smartphone
# 1       2019-11-01 06:00:00       view     5000088  appliances.sewing_machine
# 2       2019-11-01 06:00:01       view    17302664                    unknown
# 3       2019-11-01 06:00:01       view     3601530  appliances.kitchen.washer
# 4       2019-11-01 06:00:01       view     1004775     electronics.smartphone
# ...                     ...        ...         ...                        ...
# 4324040 2019-11-03 23:59:59       view     1004718     electronics.smartphone
# 4324041 2019-11-03 23:59:59       view    28716595              apparel.shoes
# 4324042 2019-11-03 23:59:59       view    28718914         apparel.shoes.keds
# 4324043 2019-11-03 23:59:59       view    22700541                    unknown
# 4324044 2019-11-03 23:59:59       view     1004956     electronics.smartphone
#
#            brand       price    user_id                          user_session  \
# 0         xiaomi  489.070007  520088904  4d3b30da-a5e4-49df-b1a8-ba5943f1dd33
# 1         janome  293.649994  530496790  8e5f4f83-366c-4f70-860e-ca7417414283
# 2          creed   28.309999  561587266  755422e7-9040-477b-9bd2-6a6e8fd97387
# 3             lg  712.869995  518085591  3bfb58cd-7892-48cc-8020-2f17e6de6e7f
# 4         xiaomi  183.270004  558856683  313628f1-68b8-460d-84f6-cec7a8796ef2
# ...          ...         ...        ...                                   ...
# 4324040    haier   77.199997  561765733  bafdd7cd-77be-42f7-8eb4-d01ec78a1703
# 4324041    baden   53.799999  515166728  3ed362b8-478e-4b1a-9d07-4bb078baca29
# 4324042  nexpero   71.820000  513822823  7a190371-70cf-4026-a140-e97468fed40d
# 4324043  unknown   14.160000  567089454  cf668a7f-19ed-4ec5-89d1-da8b755553ff
# 4324044   xiaomi  382.119995  562015918  59cf6e10-ea4e-432e-9d16-37b2c6a6d8d4
#
#          event_date  event_month  event_day day_of_week  event_hour  \
# 0        2019-11-01           11          1      Friday           6
# 1        2019-11-01           11          1      Friday           6
# 2        2019-11-01           11          1      Friday           6
# 3        2019-11-01           11          1      Friday           6
# 4        2019-11-01           11          1      Friday           6
# ...             ...          ...        ...         ...         ...
# 4324040  2019-11-03           11          3      Sunday          23
# 4324041  2019-11-03           11          3      Sunday          23
# 4324042  2019-11-03           11          3      Sunday          23
# 4324043  2019-11-03           11          3      Sunday          23
# 4324044  2019-11-03           11          3      Sunday          23
#
#          event_week
# 0                44
# 1                44
# 2                44
# 3                44
# 4                44
# ...             ...
# 4324040          44
# 4324041          44
# 4324042          44
# 4324043          44
# 4324044          44
#
# [4324045 rows x 14 columns]

# %%
# %%time
# 10월 데이터 마지막 부분에 tmp concat
df_oct = pd.concat([df_oct, tmp], axis=0).reset_index(drop=True)
df_oct
# Out:
# Wall time: 1min 34s
#                   event_time event_type  product_id  \
# 0        2019-10-01 06:00:00       view    44600062
# 1        2019-10-01 06:00:00       view     3900821
# 2        2019-10-01 06:00:01       view    17200506
# 3        2019-10-01 06:00:01       view     1307067
# 4        2019-10-01 06:00:04       view     1004237
# ...                      ...        ...         ...
# 46772804 2019-11-03 23:59:59       view     1004718
# 46772805 2019-11-03 23:59:59       view    28716595
# 46772806 2019-11-03 23:59:59       view    28718914
# 46772807 2019-11-03 23:59:59       view    22700541
# 46772808 2019-11-03 23:59:59       view     1004956
#
#                                 category_code     brand        price  \
# 0                                     unknown  shiseido    35.790001
# 1         appliances.environment.water_heater      aqua    33.200001
# 2                  furniture.living_room.sofa   unknown   543.099976
# 3                          computers.notebook    lenovo   251.740005
# 4                      electronics.smartphone     apple  1081.979980
# ...                                       ...       ...          ...
# 46772804               electronics.smartphone     haier    77.199997
# 46772805                        apparel.shoes     baden    53.799999
# 46772806                   apparel.shoes.keds   nexpero    71.820000
# 46772807                              unknown   unknown    14.160000
# 46772808               electronics.smartphone    xiaomi   382.119995
#
#             user_id                          user_session  event_date  \
# 0         541312140  72d76fde-8bb3-4e00-8c23-a032dfed738c  2019-10-01
# 1         554748717  9333dfbd-b87a-4708-9857-6336556b0fcc  2019-10-01
# 2         519107250  566511c2-e2e3-422b-b695-cf8e6e792ca8  2019-10-01
# 3         550050854  7c90fc70-0e80-4590-96f3-13c02c18c713  2019-10-01
# 4         535871217  c6bd7419-2748-4c56-95b4-8cec9ff8b80d  2019-10-01
# ...             ...                                   ...         ...
# 46772804  561765733  bafdd7cd-77be-42f7-8eb4-d01ec78a1703  2019-11-03
# 46772805  515166728  3ed362b8-478e-4b1a-9d07-4bb078baca29  2019-11-03
# 46772806  513822823  7a190371-70cf-4026-a140-e97468fed40d  2019-11-03
# 46772807  567089454  cf668a7f-19ed-4ec5-89d1-da8b755553ff  2019-11-03
# 46772808  562015918  59cf6e10-ea4e-432e-9d16-37b2c6a6d8d4  2019-11-03
#
#           event_month  event_day day_of_week  event_hour  event_week
# 0                  10          1     Tuesday           6          40
# 1                  10          1     Tuesday           6          40
# 2                  10          1     Tuesday           6          40
# 3                  10          1     Tuesday           6          40
# 4                  10          1     Tuesday           6          40
# ...               ...        ...         ...         ...         ...
# 46772804           11          3      Sunday          23          44
# 46772805           11          3      Sunday          23          44
# 46772806           11          3      Sunday          23          44
# 46772807           11          3      Sunday          23          44
# 46772808           11          3      Sunday          23          44
#
# [46772809 rows x 14 columns]

# %%
# %%time
# 11월 데이터에서 tmp drop
df_nov = df_nov.drop(tmp.index, axis=0).reset_index(drop=True)
df_nov
# Out:
# Wall time: 54.3 s
#                   event_time event_type  product_id  \
# 0        2019-11-04 00:00:00       view    26405148
# 1        2019-11-04 00:00:00       view    55000008
# 2        2019-11-04 00:00:00       view    35900057
# 3        2019-11-04 00:00:00       view     1201413
# 4        2019-11-04 00:00:00       view    12705201
# ...                      ...        ...         ...
# 63177929 2019-12-01 05:59:58       view    15700137
# 63177930 2019-12-01 05:59:58       view    28719425
# 63177931 2019-12-01 05:59:59       view     1004833
# 63177932 2019-12-01 05:59:59       view     2701706
# 63177933 2019-12-01 05:59:59       view     1004233
#
#                              category_code    brand        price    user_id  \
# 0                                  unknown  sokolov   696.799988  386908545
# 1                          apparel.costume     nike   111.949997  530192239
# 2                                  unknown   apollo    10.270000  567185457
# 3                       electronics.tablet  nexttab    47.860001  546059044
# 4                                  unknown  unknown    58.529999  519027485
# ...                                    ...      ...          ...        ...
# 63177929                           unknown  unknown   277.739990  532714000
# 63177930                     apparel.shoes    baden    62.810001  545223467
# 63177931            electronics.smartphone  samsung   167.029999  557794415
# 63177932  appliances.kitchen.refrigerators  samsung   566.270020  531607492
# 63177933            electronics.smartphone    apple  1312.520020  579969851
#
#                                   user_session  event_date  event_month  \
# 0         657eee62-2b56-40ee-be6e-63bb05623727  2019-11-04           11
# 1         2fb6b95e-3f82-4a44-966c-19c52954a977  2019-11-04           11
# 2         c44929e6-88db-4b73-a3d9-dbab1602159b  2019-11-04           11
# 3         bce815d4-0e5a-40f9-ba55-688fedec3b14  2019-11-04           11
# 4         7f561f0e-3cef-4594-84c0-8e1383c0d872  2019-11-04           11
# ...                                        ...         ...          ...
# 63177929  02b4131c-0112-4231-aafa-ceaa08e77c1b  2019-12-01           12
# 63177930  734c5eef-0742-4f8b-9d22-48f75b0bc359  2019-12-01           12
# 63177931  6fecf566-ebb0-4e70-a243-cdc13ce044cb  2019-12-01           12
# 63177932  368ddc8b-5db9-40fb-b7ff-b6582a1192c0  2019-12-01           12
# 63177933  90aca71c-ed8a-4670-866a-761ebacb732d  2019-12-01           12
#
#           event_day day_of_week  event_hour  event_week
# 0                 4      Monday           0          45
# 1                 4      Monday           0          45
# 2                 4      Monday           0          45
# 3                 4      Monday           0          45
# 4                 4      Monday           0          45
# ...             ...         ...         ...         ...
# 63177929          1      Sunday           5          48
# 63177930          1      Sunday           5          48
# 63177931          1      Sunday           5          48
# 63177932          1      Sunday           5          48
# 63177933          1      Sunday           5          48
#
# [63177934 rows x 14 columns]

# %%
tmp = df_nov[(df_nov['event_month'] == 12)]
tmp
# Out:
#                   event_time event_type  product_id  \
# 62935187 2019-12-01 00:00:00       view     1004836
# 62935188 2019-12-01 00:00:00       view    11400258
# 62935189 2019-12-01 00:00:00       view     1307545
# 62935190 2019-12-01 00:00:00       view     1004768
# 62935191 2019-12-01 00:00:00       view    12715113
# ...                      ...        ...         ...
# 63177929 2019-12-01 05:59:58       view    15700137
# 63177930 2019-12-01 05:59:58       view    28719425
# 63177931 2019-12-01 05:59:59       view     1004833
# 63177932 2019-12-01 05:59:59       view     2701706
# 63177933 2019-12-01 05:59:59       view     1004233
#
#                              category_code     brand        price    user_id  \
# 62935187            electronics.smartphone   samsung   229.589996  569472327
# 62935188                           unknown     remax    33.439999  512557400
# 62935189                computers.notebook    lenovo   244.250000  529142459
# 62935190            electronics.smartphone   samsung   236.759995  517400544
# 62935191                           unknown  kormoran    66.930000  579738611
# ...                                    ...       ...          ...        ...
# 63177929                           unknown   unknown   277.739990  532714000
# 63177930                     apparel.shoes     baden    62.810001  545223467
# 63177931            electronics.smartphone   samsung   167.029999  557794415
# 63177932  appliances.kitchen.refrigerators   samsung   566.270020  531607492
# 63177933            electronics.smartphone     apple  1312.520020  579969851
#
#                                   user_session  event_date  event_month  \
# 62935187  aeaec12c-e61a-4441-bf0c-2d57345474fb  2019-12-01           12
# 62935188  c4b6a648-cf78-4ce6-99a6-675c43b77d80  2019-12-01           12
# 62935189  6e28b9ce-a8d3-40c1-b8cc-bbd3164ccc86  2019-12-01           12
# 62935190  1713438a-b29c-4cc6-b416-853a1e888248  2019-12-01           12
# 62935191  5c0e70ac-3d8d-4a64-be47-7d608b4cdb94  2019-12-01           12
# ...                                        ...         ...          ...
# 63177929  02b4131c-0112-4231-aafa-ceaa08e77c1b  2019-12-01           12
# 63177930  734c5eef-0742-4f8b-9d22-48f75b0bc359  2019-12-01           12
# 63177931  6fecf566-ebb0-4e70-a243-cdc13ce044cb  2019-12-01           12
# 63177932  368ddc8b-5db9-40fb-b7ff-b6582a1192c0  2019-12-01           12
# 63177933  90aca71c-ed8a-4670-866a-761ebacb732d  2019-12-01           12
#
#           event_day day_of_week  event_hour  event_week
# 62935187          1      Sunday           0          48
# 62935188          1      Sunday           0          48
# 62935189          1      Sunday           0          48
# 62935190          1      Sunday           0          48
# 62935191          1      Sunday           0          48
# ...             ...         ...         ...         ...
# 63177929          1      Sunday           5          48
# 63177930          1      Sunday           5          48
# 63177931          1      Sunday           5          48
# 63177932          1      Sunday           5          48
# 63177933          1      Sunday           5          48
#
# [242747 rows x 14 columns]

# %%
# %%time
# 11월 데이터에서 tmp drop
df_nov = df_nov.drop(tmp.index, axis=0).reset_index(drop=True)
df_nov
# Out:
# Wall time: 24.5 s
#                   event_time event_type  product_id  \
# 0        2019-11-04 00:00:00       view    26405148
# 1        2019-11-04 00:00:00       view    55000008
# 2        2019-11-04 00:00:00       view    35900057
# 3        2019-11-04 00:00:00       view     1201413
# 4        2019-11-04 00:00:00       view    12705201
# ...                      ...        ...         ...
# 62935182 2019-11-30 23:59:59       view     1004751
# 62935183 2019-11-30 23:59:59       view     4300392
# 62935184 2019-11-30 23:59:59       view     2900569
# 62935185 2019-11-30 23:59:59       view     1306951
# 62935186 2019-11-30 23:59:59       view    26400378
#
#                          category_code    brand        price    user_id  \
# 0                              unknown  sokolov   696.799988  386908545
# 1                      apparel.costume     nike   111.949997  530192239
# 2                              unknown   apollo    10.270000  567185457
# 3                   electronics.tablet  nexttab    47.860001  546059044
# 4                              unknown  unknown    58.529999  519027485
# ...                                ...      ...          ...        ...
# 62935182        electronics.smartphone  samsung   192.770004  579737238
# 62935183                       unknown    vitek    23.139999  566828985
# 62935184  appliances.kitchen.microwave       lg   102.709999  518637498
# 62935185            computers.notebook    apple  2329.530029  557228009
# 62935186                       unknown  unknown   165.770004  515204478
#
#                                   user_session  event_date  event_month  \
# 0         657eee62-2b56-40ee-be6e-63bb05623727  2019-11-04           11
# 1         2fb6b95e-3f82-4a44-966c-19c52954a977  2019-11-04           11
# 2         c44929e6-88db-4b73-a3d9-dbab1602159b  2019-11-04           11
# 3         bce815d4-0e5a-40f9-ba55-688fedec3b14  2019-11-04           11
# 4         7f561f0e-3cef-4594-84c0-8e1383c0d872  2019-11-04           11
# ...                                        ...         ...          ...
# 62935182  67787d24-25fd-4dfc-80e5-c642877cd84a  2019-11-30           11
# 62935183  2954305a-def3-4a24-9d8a-129fe87938c4  2019-11-30           11
# 62935184  8cb2fad3-10cc-4c14-9eb6-c03276a90738  2019-11-30           11
# 62935185  a598f21a-6710-4072-a4e1-4c9656cef9fb  2019-11-30           11
# 62935186  d7ca2484-e2e8-40c6-ae25-79cc5e6fd8a0  2019-11-30           11
#
#           event_day day_of_week  event_hour  event_week
# 0                 4      Monday           0          45
# 1                 4      Monday           0          45
# 2                 4      Monday           0          45
# 3                 4      Monday           0          45
# 4                 4      Monday           0          45
# ...             ...         ...         ...         ...
# 62935182         30    Saturday          23          48
# 62935183         30    Saturday          23          48
# 62935184         30    Saturday          23          48
# 62935185         30    Saturday          23          48
# 62935186         30    Saturday          23          48
#
# [62935187 rows x 14 columns]

# %%
#concat category 데이터가 object로 변경 되어 버림
#기존에 없던 카테고리 데이터가 신규로 생성되어서 오브젝트로 변한것으로 추정 됨
#기존과 카테고리가 같은 경우는 그대로 category 형태로 남아있음
df_oct.dtypes
# Out:
# event_time       datetime64[ns]
# event_type             category
# product_id                int32
# category_code            object
# brand                    object
# price                   float32
# user_id                   int32
# user_session             object
# event_date               object
# event_month               int32
# event_day                 int32
# day_of_week            category
# event_hour                int32
# event_week               UInt32
# dtype: object

# %%
df_oct['event_date'] = pd.to_datetime(df_oct['event_date'], format = '%Y-%m-%d')
df_nov['event_date'] = pd.to_datetime(df_nov['event_date'], format = '%Y-%m-%d')

# %%
df_oct[['category_code','brand','user_session']] = df_oct[['category_code','brand','user_session']].astype('category')
df_nov[['category_code','brand','user_session']] = df_nov[['category_code','brand','user_session']].astype('category')

# %%
df_oct.dtypes
# Out:
# event_time       datetime64[ns]
# event_type             category
# product_id                int32
# category_code          category
# brand                  category
# price                   float32
# user_id                   int32
# user_session           category
# event_date       datetime64[ns]
# event_month               int32
# event_day                 int32
# day_of_week            category
# event_hour                int32
# event_week               UInt32
# dtype: object

# %% [markdown]
# # Export cleaned Parquet

# %%
# %%time
df_oct.to_parquet('../e-commerce/input/2019-Oct_cleaned.parquet', engine='pyarrow', index=False)
df_nov.to_parquet('../e-commerce/input/2019-Nov_cleaned.parquet', engine='pyarrow', index=False)
# Out:
# Wall time: 1min 51s

# %%
# %%time
df_dec.to_parquet('../e-commerce/input/2019-Dec_cleaned.parquet', engine='pyarrow', index=False)
df_jan.to_parquet('../e-commerce/input/2020-Jan_cleaned.parquet', engine='pyarrow', index=False)
df_feb.to_parquet('../e-commerce/input/2020-Feb_cleaned.parquet', engine='pyarrow', index=False)
df_mar.to_parquet('../e-commerce/input/2020-Mar_cleaned.parquet', engine='pyarrow', index=False)
df_apr.to_parquet('../e-commerce/input/2020-Apr_cleaned.parquet', engine='pyarrow', index=False)
# Out:
# Wall time: 2min 6s

# %% [markdown]
# # +@ 전처리 for 추천시스템

# %%
# 전처리된 데이터셋 불러오기
df_oct = pd.read_parquet('../e-commerce/input/2019-Oct_cleaned.parquet')
# Out:
# ---------------------------------------------------------------------------
# ArrowMemoryError                          Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_13316/3532524104.py in <module>
#       1 # 전처리된 데이터셋 불러오기
# ----> 2 df_oct = pd.read_parquet('../e-commerce/input/2019-Oct_cleaned.parquet')
#
# ~\anaconda3\lib\site-packages\pandas\io\parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     491     impl = get_engine(engine)
#     492
# --> 493     return impl.read(
#     494         path,
#     495         columns=columns,
#
# ~\anaconda3\lib\site-packages\pandas\io\parquet.py in read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     238         )
#     239         try:
# --> 240             result = self.api.parquet.read_table(
#     241                 path_or_handle, columns=columns, **kwargs
#     242             ).to_pandas(**to_pandas_kwargs)
#
# ~\anaconda3\lib\site-packages\pyarrow\array.pxi in pyarrow.lib._PandasConvertible.to_pandas()
#
# ~\anaconda3\lib\site-packages\pyarrow\table.pxi in pyarrow.lib.Table._to_pandas()
#
# ~\anaconda3\lib\site-packages\pyarrow\pandas_compat.py in table_to_blockmanager(options, table, categories, ignore_metadata, types_mapper)
#     801     _check_data_column_metadata_consistency(all_columns)
#     802     columns = _deserialize_column_index(table, all_columns, column_indexes)
# --> 803     blocks = _table_to_blocks(options, table, categories, ext_columns_dtypes)
#     804
#     805     axes = [columns, index]
#
# ~\anaconda3\lib\site-packages\pyarrow\pandas_compat.py in _table_to_blocks(options, block_table, categories, extension_columns)
#    1151     # Convert an arrow table to Block from the internal pandas API
#    1152     columns = block_table.column_names
# -> 1153     result = pa.lib.table_to_blocks(options, block_table, categories,
#    1154                                     list(extension_columns.keys()))
#    1155     return [_reconstruct_block(item, columns, extension_columns)
#
# ~\anaconda3\lib\site-packages\pyarrow\table.pxi in pyarrow.lib.table_to_blocks()
#
# ~\anaconda3\lib\site-packages\pyarrow\error.pxi in pyarrow.lib.check_status()
#
# ArrowMemoryError: malloc of size 187091264 failed

# %% [markdown]
# ### 📌 가격이 0이하인 데이터 제거하기

# %%
# price가 0 이하인 경우는 비정상적인 캐아스이고, 이런 데이터가 존재하는지 먼저 알아봄
print('10월 데이터 중 price가 0 이하인 데이터 수: ', df_oct[df_oct['price']<=0].price.count())

# %%
# 데이터 제거하기
df_oct = df_oct[df_oct['price'] > 0]

# %% [markdown]
# ### 📌 제거 후 데이터셋 크기 및 컬럼 타입 확인

# %%
# 제거 후 데이터셋 크기 및 컬럼 타입 확인
print(df_oct.shape)
df_oct.head(3)

# %%
print('10월 데이터 타입 확인: \n', df_oct.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_20384/419966544.py in <module>
# ----> 1 print('10월 데이터 타입 확인: \n', df_oct.dtypes)
#
# NameError: name 'df_oct' is not defined

# %% [markdown]
# ### 📌  컬럼 타입 변환
# - `category_code`: `category -> str`
# - `brand`: `category -> str`

# %%
# category_code, brand: vectorization을 위해 타입 문자열로 변환
df_oct['category_code'] = df_oct['category_code'].astype('str')
df_oct['brand'] = df_oct['brand'].astype('str')
df_oct['product_id'] = df_oct['product_id'].astype('str')

# %%
print('10월 데이터 타입 확인(타입변환 후): \n', df_oct.dtypes)
# Out:
# 10월 데이터 타입 확인(타입변환 후):
#  event_time       datetime64[ns]
# event_type             category
# product_id                int32
# category_code            object
# brand                    object
# price                   float32
# user_id                   int32
# user_session           category
# event_date       datetime64[ns]
# event_month               int32
# event_day                 int32
# day_of_week            category
# event_hour                int32
# event_week               UInt32
# dtype: object

# %% [markdown]
# ### 📌 unknown이라 표기된 결측치 제거
# - cateogory_code, brand가 unknown이면 추천 시스템에 사용할 수 없으므로 제거

# %%
# unknown이라 표기된 결측치 제거 (추천에 방해된다고 판단)

# 1) category_code == unknown인 경우의 인덱스 보여주는 조건문
cat_con = df_oct[df_oct['category_code'] == 'unknown'].index        
df_oct.drop(cat_con, inplace=True)          # 제거

# 2) brand == unknown인 경우의 인덱스 보여주는 조건문
brand_con = df_oct[df_oct['brand'] == 'unknown'].index              
df_oct.drop(brand_con, inplace=True)        # 제거

# %% [markdown]
# ###  ✅ 필요한 전처리를 거친 데이터를 다시 parquet 파일로 저장하기
# - 이후 과정을 편하게 하기 위해 전처리를 거친 데이터 파일 따로 생성해 나중에 로드하려 함

# %%
# 내보내기
df_oct.to_parquet('../e-commerce/input/2019-Oct_new.parquet', engine='pyarrow', index=False)
